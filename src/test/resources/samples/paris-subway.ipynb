# %% [markdown]
# # Paris Subway Data

# %% [markdown]
# This will create a simple model of Paris Subway.
#
# Based on the RATP open dataset  (the transport company in Paris) : https://dataratp.opendatasoft.com/
#
# The dataset can be retrieve using this link : https://dataratp.opendatasoft.com/explore/dataset/offre-transport-de-la-ratp-format-gtfs/information/
#
# All possibilities will not be take into account. This is only for testing purpose. Feel free to improve it.

# %%
from dataclasses import dataclass
import pandas as pd
from hashlib import sha1
from jinja2 import Template
import dateutil.parser as dateparser
from datetime import datetime, timedelta

# Force some reset ...
pd.reset_option("display.max_rows")

# %% [markdown]
# ### Constants

# %%
OUTPUT_FILE = 'paris-subway.cypher'
SUBWAY_LINES = list(map(str, range(1,15))) + ['3B', '7B']
# SUBWAY_LINES = ['10', '14', '3']

# Show result
#SUBWAY_LINES

# %% [markdown]
# ### Functions
#
# * `hash_str` : produce a hexa sha1 format of a string
# * `date_parser` : parse a date
#   * `24:15:35` => `datetime(2020, 1, 1, 0, 15, 35)`
#   * `00:15:35` => `datetime(2020, 1, 1, 0, 15, 35)`
# * `diff_second` : calculate the second between 2 dates
#   * `to_time=date_parser('24:15:35'), from_time=date_parser('24:14:35')` => `60`
#   * `to_time=date_parser('00:02:35'), from_time=date_parser('23:59:35')` => `180`

# %%
def hash_str(value: str):
    return sha1(str(value).encode('utf-8')).hexdigest()

def date_parser(value: str):
    p = value.split(':')
    d = dateparser.parse(f'{(int(p[0]) % 24):02}:{(int(p[1]) % 60):02}:{(int(p[2]) % 60):02}')
    return d.replace(year=2020, month=1, day=1)

def diff_second(to_time, from_time):
    if to_time < from_time:
        to_time = to_time + timedelta(days=1)
    return int((to_time - from_time).total_seconds())

# %% [markdown]
# ## Loading CSV Data
#
# Each CSV will be load. Data which will no be used will be drop.

# %% [markdown]
# ### Load CSV : `routes.txt` : `routes_df`
#
# * Drop columns : `['agency_id', 'route_desc', 'route_url', 'route_color', 'route_text_color', 'route_type']`
# * Filter on : `SUBWAY_LINES`
# * Reset index

# %%
routes_df = pd.read_csv(
    'routes.txt',
    dtype={ 'route_id': int, 'route_short_name': str, 'route_long_name': str }
)
routes_df = routes_df.drop(
    columns=['agency_id', 'route_desc', 'route_url', 'route_color', 'route_text_color', 'route_type']
)

if SUBWAY_LINES:
    routes_df = routes_df[( routes_df['route_short_name'].isin(SUBWAY_LINES) )]

routes_df = routes_df.reset_index(drop=True)
routes_df.head(5)
# Out:
#    route_id route_short_name  \
# 0   2272462                5
# 1   2272463                5
# 2   2272466                7
# 3   2272467                7
# 4   2272468                7
#
#                                      route_long_name
# 0  (BOBIGNY - PABLO PICASSO <-> PLACE D'ITALIE) -...
# 1  (BOBIGNY - PABLO PICASSO <-> PLACE D'ITALIE) -...
# 2  (LA COURNEUVE - 8 MAI 1945 <-> VILLEJUIF-L. AR...
# 3  (LA COURNEUVE - 8 MAI 1945 <-> VILLEJUIF-L. AR...
# 4  (LA COURNEUVE - 8 MAI 1945 <-> VILLEJUIF-L. AR...

# %% [markdown]
# ### Load CSV `trips.txt` : `trips_df`
#
# * Drop columns : `['service_id', 'trip_headsign', 'trip_short_name', 'direction_id', 'shape_id']`
# * Merge with `routes_df` on key `route_id`
# * Reset index

# %%
trips_df = pd.read_csv(
    'trips.txt',
    dtype={'route_id':int, 'trip_id':int, 'trip_headsign':str, 'trip_short_name':str}
)
trips_df = trips_df.drop(columns=['service_id', 'trip_headsign', 'trip_short_name', 'direction_id', 'shape_id'])
trips_df = pd.merge(trips_df, routes_df, on='route_id').reset_index(drop=True)
trips_df
# Out:
#         route_id            trip_id route_short_name  \
# 0        2272462  26231428312203953                5
# 1        2272462  26331428312203953                5
# 2        2272462  26431428312203953                5
# 3        2272462  26531428312203953                5
# 4        2272462  26631428312203953                5
# ...          ...                ...              ...
# 108670   2416131   9534576491078872                1
# 108671   2416131   9634576491078872                1
# 108672   2416131   9734576491078872                1
# 108673   2416131   9834576491078872                1
# 108674   2416131   9934576491078872                1
#
#                                           route_long_name
# 0       (BOBIGNY - PABLO PICASSO <-> PLACE D'ITALIE) -...
# 1       (BOBIGNY - PABLO PICASSO <-> PLACE D'ITALIE) -...
# 2       (BOBIGNY - PABLO PICASSO <-> PLACE D'ITALIE) -...
# 3       (BOBIGNY - PABLO PICASSO <-> PLACE D'ITALIE) -...
# 4       (BOBIGNY - PABLO PICASSO <-> PLACE D'ITALIE) -...
# ...                                                   ...
# 108670     (CHATEAU DE VINCENNES <-> LA DEFENSE) - Retour
# 108671     (CHATEAU DE VINCENNES <-> LA DEFENSE) - Retour
# 108672     (CHATEAU DE VINCENNES <-> LA DEFENSE) - Retour
# 108673     (CHATEAU DE VINCENNES <-> LA DEFENSE) - Retour
# 108674     (CHATEAU DE VINCENNES <-> LA DEFENSE) - Retour
#
# [108675 rows x 4 columns]

# %% [markdown]
# ### Load `stop_times.txt` : `stop_times_df`
#
# <div class="alert alert-block alert-warning">
# This file may take a while to be loaded. `stop_times.txt` is pretty large (currently: `616.81MB`)
# </div>
#
# In this file, all trips are describe with the arrival and departure times in each stops.
#
# * Drop columns : `['stop_headsign', 'shape_dist_traveled']`
# * Merge with `trips_df` on key `trip_id`
# * Transform columns
#   * `arrival_time` into `datetime`
#   * `departure_time` into `datetime`
# * Reset index

# %%
stop_times_df = pd.read_csv(
    'stop_times.txt',
    dtype={'trip_id':int, 'stop_id':int, 'arrival_time':str, 'departure_time':str}
)
stop_times_df = stop_times_df.drop(columns=['stop_headsign', 'shape_dist_traveled'])
stop_times_df = pd.merge(stop_times_df, trips_df, on='trip_id')
stop_times_df['arrival_time'] = stop_times_df['arrival_time'].apply(date_parser)
stop_times_df['departure_time'] = stop_times_df['departure_time'].apply(date_parser)
stop_times_df = stop_times_df.reset_index(drop=True)
stop_times_df
# Out:
#                    trip_id        arrival_time      departure_time  stop_id  \
# 0        10031412331078871 2020-01-01 14:01:00 2020-01-01 14:01:00     2035
# 1        10031412331078871 2020-01-01 14:03:00 2020-01-01 14:03:00     2067
# 2        10031412331078871 2020-01-01 14:04:00 2020-01-01 14:04:00     1725
# 3        10031412331078871 2020-01-01 14:06:00 2020-01-01 14:06:00     1751
# 4        10031412331078871 2020-01-01 14:07:00 2020-01-01 14:07:00     1832
# ...                    ...                 ...                 ...      ...
# 2617116   9934576502416128 2020-01-01 12:48:00 2020-01-01 12:48:00     2110
# 2617117   9934576502416128 2020-01-01 12:49:00 2020-01-01 12:49:00     2152
# 2617118   9934576502416128 2020-01-01 12:50:00 2020-01-01 12:50:00     2535
# 2617119   9934576502416128 2020-01-01 12:51:00 2020-01-01 12:51:00     2478
# 2617120   9934576502416128 2020-01-01 12:52:00 2020-01-01 12:52:00     2420
#
#          stop_sequence  route_id route_short_name  \
# 0                    1   2416130                1
# 1                    2   2416130                1
# 2                    3   2416130                1
# 3                    4   2416130                1
# 4                    5   2416130                1
# ...                ...       ...              ...
# 2617116             23   2299375                4
# 2617117             24   2299375                4
# 2617118             25   2299375                4
# 2617119             26   2299375                4
# 2617120             27   2299375                4
#
#                                            route_long_name
# 0            (CHATEAU DE VINCENNES <-> LA DEFENSE) - Aller
# 1            (CHATEAU DE VINCENNES <-> LA DEFENSE) - Aller
# 2            (CHATEAU DE VINCENNES <-> LA DEFENSE) - Aller
# 3            (CHATEAU DE VINCENNES <-> LA DEFENSE) - Aller
# 4            (CHATEAU DE VINCENNES <-> LA DEFENSE) - Aller
# ...                                                    ...
# 2617116  (PORTE DE CLIGNANCOURT <-> MAIRIE DE MONTROUGE...
# 2617117  (PORTE DE CLIGNANCOURT <-> MAIRIE DE MONTROUGE...
# 2617118  (PORTE DE CLIGNANCOURT <-> MAIRIE DE MONTROUGE...
# 2617119  (PORTE DE CLIGNANCOURT <-> MAIRIE DE MONTROUGE...
# 2617120  (PORTE DE CLIGNANCOURT <-> MAIRIE DE MONTROUGE...
#
# [2617121 rows x 8 columns]

# %% [markdown]
# ### Load `stops.txt` : `stops_df`
#
# * Load CSV `stops.txt`
# * Drop columns : `['stop_code', 'stop_desc', 'location_type', 'parent_station']`
# * Merge with `stop_times_df['stop_id']` on `stop_id`
# * Drop duplicates
# * Reset index

# %%
stops_df = pd.read_csv(
    'stops.txt',
    dtype={'trip_id':int, 'stop_id':int, 'trip_headsign':str, 'trip_short_name':str}
)
stops_df = stops_df.drop(columns=['stop_code', 'stop_desc', 'location_type', 'parent_station'])
stops_df["station_id"] = stops_df["stop_name"].apply(hash_str)
stops_df = pd.merge(stops_df, stop_times_df['stop_id'], on=['stop_id']).drop_duplicates()
stops_df = stops_df.reset_index(drop=True)
stops_df = stops_df.rename(columns={
    'stop_name': 'name',
    'stop_lat': 'lat',
    'stop_lon': 'lon'
})
stops_df.head(5)
# Out:
#    stop_id                              name        lat       lon  \
# 0  1166824                        Olympiades  48.826948  2.367038
# 1  1166825                        Olympiades  48.826948  2.367038
# 2  1166826  Bibliothèque-François Mitterrand  48.829831  2.376120
# 3  1166827  Bibliothèque-François Mitterrand  48.829831  2.376120
# 4  1166828                Cour Saint-Emilion  48.833521  2.386265
#
#                                  station_id
# 0  c013a983778accb3494ea2b6e2d62d9b364f53f6
# 1  c013a983778accb3494ea2b6e2d62d9b364f53f6
# 2  e799ff89f02653528c8660989938659f86e200ec
# 3  e799ff89f02653528c8660989938659f86e200ec
# 4  757558be993d3632918145952a6b1e785d75c347

# %% [markdown]
# ### Load `transfers.txt` : `transfers_df`
#
# * Load CSV `transfers_df`
# * Reject all values where :
#   * `from_stop_id` don't belong to `stops_df['stop_id']`
#   * `to_stop_id` don't belong to `stops_df['stop_id']`
# * Reset index

# %%
transfers_df = pd.read_csv(
    'transfers.txt',
    dtype={'from_stop_id':int, 'to_stop_id':int, 'transfer_type':int, 'min_transfer_time':int}
)
transfers_df = transfers_df[( transfers_df['from_stop_id'].isin(stops_df['stop_id']) )]
transfers_df = transfers_df[( transfers_df['to_stop_id'].isin(stops_df['stop_id']) )]
transfers_df = transfers_df.reset_index(drop=True)
transfers_df.head(5)
# Out:
#    from_stop_id  to_stop_id  transfer_type  min_transfer_time
# 0       1166832        1955              2                420
# 1       1166832        2210              2                240
# 2       1166833        1955              2                420
# 3       1166833        2210              2                240
# 4       1166834        1965              2                420

# %% [markdown]
# ## Transformations
#
# Apply some transformation on data to generate a simple cypher for Neo4J

# %% [markdown]
# ### Lines : `lines_df`
#
# * Based on `routes_df`
# * Take only column `route_short_name`
# * Drop duplicates
# * Rename columns `route_short_name` into `name`
# * Integrate hash for line

# %%
lines_df = routes_df['route_short_name'].to_frame()
lines_df = lines_df.drop_duplicates()
lines_df = lines_df.rename(columns={'route_short_name': 'name'})
lines_df['line_id'] = lines_df['name'].apply(hash_str) 
lines_df.head(5)
# Out:
#    name                                   line_id
# 0     5  ac3478d69a3c81fa62e60f5c3696165a4e5e6ac4
# 2     7  902ba3cda1883801594b6e1b452790cc53948fda
# 6    7B  c274b3c0dad677526355847743c36dfa47899f46
# 8     9  0ade7c2cf97f75d009975f4d720d1fa6c19f4897
# 10   10  b1d5781111d84f7b3fe45a0852e59758cd7a87e5

# %% [markdown]
# ### Stations : `stations_df`
#
# * Based on `stop_times_df` & `stops_df`
# * Drop columns `stop_id` of `stops_df`
# * Rename columns
# * Drop duplicates
# * Group by `station_id` and aggregate `line`
# * Drop columns `line`
# * Drop duplicate based on `station_id`
# * Reset index

# %%
stations_df = stop_times_df.drop(columns=['trip_id', 'arrival_time', 'departure_time', 'stop_sequence'])
stations_df = pd.merge(stops_df, stations_df, on=['stop_id'])
stations_df = stations_df.drop(columns=['route_id', 'route_long_name', 'stop_id'])
stations_df = stations_df.rename(columns={'route_short_name': 'line'})
stations_df = stations_df.drop_duplicates()
_tmp = stations_df.groupby(['station_id']).agg(lines=('line', list)).reset_index()
stations_df = stations_df.drop(columns=['line']).drop_duplicates()
stations_df = pd.merge(stations_df, _tmp, on=['station_id'])
del _tmp
stations_df = stations_df.drop_duplicates(subset=['station_id']).reset_index()
stations_df.head(10)
# Out:
#    index                              name        lat       lon  \
# 0      0                        Olympiades  48.826948  2.367038
# 1      1  Bibliothèque-François Mitterrand  48.829831  2.376120
# 2      2                Cour Saint-Emilion  48.833521  2.386265
# 3      3                             Bercy  48.840543  2.379409
# 4      5                      Gare de Lyon  48.844652  2.373108
# 5      7                          Châtelet  48.858956  2.347361
# 6     12                         Madeleine  48.869579  2.324162
# 7     15                      Saint-Lazare  48.875538  2.325196
# 8     19            Saint-Denis-Université  48.946111  2.362045
# 9     20                          Villiers  48.881324  2.316597
#
#                                  station_id              lines
# 0  c013a983778accb3494ea2b6e2d62d9b364f53f6               [14]
# 1  e799ff89f02653528c8660989938659f86e200ec               [14]
# 2  757558be993d3632918145952a6b1e785d75c347               [14]
# 3  51cac4e9016ad7dc7f036283af508252b245b360            [14, 6]
# 4  49541b7895349f795ad38c3b7fc249aec6b490b7            [14, 1]
# 5  ae9c8e1611f553fd7dc21d399dc4161a788ca201  [14, 4, 11, 7, 1]
# 6  3f6701fa5352e7df067b97a9ae7c9131d57f6472        [14, 12, 8]
# 7  9312306d63bb3b64ed9d6092ec90f7c194d27a93    [14, 3, 12, 13]
# 8  f85e6dfb1bc7fad3573a86527a6e1f6f49662be4               [13]
# 9  33a3c8c64eb4fe122a6a0e3ee083ac2018576639             [2, 3]

# %% [markdown]
# ### Filter complete routes : `complete_stop_times_df`
#
# Skip all routes that may not be complete
#
# On partial routes :
# * a stop may be skipped
# * the terminus can be in the middle of the lines

# %%
_tmp_stops = stops_df.drop(columns=['name', 'lat', 'lon'])
route_having_max_seq_series = stop_times_df.groupby('route_id')['stop_sequence'].idxmax()
complete_route_id_series = stop_times_df.loc[route_having_max_seq_series]['route_id']
complete_stop_times_df = pd.merge(stop_times_df, complete_route_id_series, on=['route_id'])
complete_stop_times_df = pd.merge(complete_stop_times_df, _tmp_stops, on=['stop_id'])
del _tmp_stops
complete_stop_times_df.head(5)
# Out:
#              trip_id        arrival_time      departure_time  stop_id  \
# 0  10031412331078871 2020-01-01 14:01:00 2020-01-01 14:01:00     2035
# 1  10031412351078871 2020-01-01 14:15:00 2020-01-01 14:15:00     2035
# 2  10031412391078871 2020-01-01 09:13:00 2020-01-01 09:13:00     2035
# 3  10031412401078871 2020-01-01 09:19:00 2020-01-01 09:19:00     2035
# 4  10031412441078871 2020-01-01 13:10:00 2020-01-01 13:10:00     2035
#
#    stop_sequence  route_id route_short_name  \
# 0              1   2416130                1
# 1              1   2416130                1
# 2              1   2416130                1
# 3              1   2416130                1
# 4              1   2416130                1
#
#                                  route_long_name  \
# 0  (CHATEAU DE VINCENNES <-> LA DEFENSE) - Aller
# 1  (CHATEAU DE VINCENNES <-> LA DEFENSE) - Aller
# 2  (CHATEAU DE VINCENNES <-> LA DEFENSE) - Aller
# 3  (CHATEAU DE VINCENNES <-> LA DEFENSE) - Aller
# 4  (CHATEAU DE VINCENNES <-> LA DEFENSE) - Aller
#
#                                  station_id
# 0  9e23e8f481e69e44a5d39b27f4f664061aa934f7
# 1  9e23e8f481e69e44a5d39b27f4f664061aa934f7
# 2  9e23e8f481e69e44a5d39b27f4f664061aa934f7
# 3  9e23e8f481e69e44a5d39b27f4f664061aa934f7
# 4  9e23e8f481e69e44a5d39b27f4f664061aa934f7

# %% [markdown]
# ### Travel between 2 stops : `stop_travels_df`
#
# <div class="alert alert-block alert-warning">
# This can take time... Based on `complete_stop_times_df`, many operations will be done.
# </div>
#
# * Based on `complete_stop_times_df`
# * Create 2 DataFrames :
#   * `_from_stops_df` : where we came from (rename columns)
#   * `_to_stops_df` : where we are going to (rename columns)
# * Merge this 2 DataFrames to create a new one : `stop_travels_df`
# * Calculate the :
#   * `arrival_duration` : Diff of seconds between stops based on the `arrival_time`
#   * `departure_duration` : Diff of seconds between stops based on the `departure_time`

# %%
_base_stops_df = complete_stop_times_df.drop(columns=['route_long_name'])

# From stops
_from_stops_df = _base_stops_df.rename(
    columns={
        'stop_id': 'from_stop_id',
        'stop_name': 'from_stop_name',
        'station_id': 'from_station_id',
        'stop_sequence': 'from_stop_sequence',
        'arrival_time': 'from_arrival_time',
        'departure_time': 'from_departure_time',
    }
)
_from_stops_df['to_stop_sequence'] = _from_stops_df['from_stop_sequence'] + 1

# Next stops
_to_stops_df = _base_stops_df.drop(columns=['route_id', 'route_short_name'])
_to_stops_df = _to_stops_df.rename(
    columns={
        'stop_id': 'to_stop_id',
        'stop_name': 'to_stop_name',
        'station_id': 'to_station_id',
        'stop_sequence': 'to_stop_sequence',
        'arrival_time': 'to_arrival_time',
        'departure_time': 'to_departure_time',
    }
)

# Merge
stop_travels_df = pd.merge(_from_stops_df, _to_stops_df, on=[ 'trip_id', 'to_stop_sequence'])

# Clean
del _base_stops_df
del _from_stops_df
del _to_stops_df

# Calculate duration diffs
_arrival_diff = lambda x: diff_second(x.to_arrival_time, x.from_arrival_time)
_departure_diff = lambda x: diff_second(x.to_departure_time, x.from_departure_time)
stop_travels_df['arrival_duration'] = stop_travels_df.apply(_arrival_diff, axis=1)
stop_travels_df['departure_duration'] = stop_travels_df.apply(_departure_diff, axis=1)

# Remove useles columns
stop_travels_df = stop_travels_df.drop(columns=[
    'from_stop_sequence', 'from_arrival_time', 'from_departure_time',
    'to_stop_sequence', 'to_arrival_time', 'to_departure_time'
])
stop_travels_df = stop_travels_df.reset_index(drop=True)

# Clean
del _arrival_diff
del _departure_diff

stop_travels_df.head(5)
# Out:
#              trip_id  from_stop_id  route_id route_short_name  \
# 0  10031412331078871          2035   2416130                1
# 1  10031412351078871          2035   2416130                1
# 2  10031412391078871          2035   2416130                1
# 3  10031412401078871          2035   2416130                1
# 4  10031412441078871          2035   2416130                1
#
#                             from_station_id  to_stop_id  \
# 0  9e23e8f481e69e44a5d39b27f4f664061aa934f7        2067
# 1  9e23e8f481e69e44a5d39b27f4f664061aa934f7        2067
# 2  9e23e8f481e69e44a5d39b27f4f664061aa934f7        2067
# 3  9e23e8f481e69e44a5d39b27f4f664061aa934f7        2067
# 4  9e23e8f481e69e44a5d39b27f4f664061aa934f7        2067
#
#                               to_station_id  arrival_duration  \
# 0  5b02b0e7ad4f13515b5b21e41413a312bb3a1656               120
# 1  5b02b0e7ad4f13515b5b21e41413a312bb3a1656               120
# 2  5b02b0e7ad4f13515b5b21e41413a312bb3a1656               120
# 3  5b02b0e7ad4f13515b5b21e41413a312bb3a1656                60
# 4  5b02b0e7ad4f13515b5b21e41413a312bb3a1656                60
#
#    departure_duration
# 0                 120
# 1                 120
# 2                 120
# 3                  60
# 4                  60

# %% [markdown]
# ### Travels : `travels_df`
#
# * Based on `stop_travels_df`
# * Grouping by `from_stop_id` and `to_stop_id`
# * Calculate the mean of duration between the stop `from_stop_id` and `to_stop_id`
# * Remove columns `['trip_id', 'arrival_duration', 'departure_duration']`
# * Drop duplicates

# %%
# Calculate mean time between 2 stops
_stop_means = stop_travels_df.groupby(['from_stop_id', 'to_stop_id'])[['arrival_duration', 'departure_duration']].mean()
_stop_means = _stop_means.reset_index()
_stop_means['mean_transfer_time'] = _stop_means[['arrival_duration', 'departure_duration']].mean(axis=1)
_stop_means['mean_transfer_time'] = _stop_means['mean_transfer_time'].astype(int)
_stop_means = _stop_means.drop(columns=['arrival_duration', 'departure_duration'])
# Merge & Clean
travels_df = pd.merge(stop_travels_df, _stop_means, on=[ 'from_stop_id', 'to_stop_id'])
travels_df = travels_df.drop(columns=['trip_id', 'arrival_duration', 'departure_duration'])
travels_df = travels_df.drop_duplicates().reset_index(drop=True)
travels_df
# Out:
#      from_stop_id  route_id route_short_name  \
# 0            2035   2416130                1
# 1            2035   2416130                1
# 2            2067   2416130                1
# 3            1725   2416130                1
# 4            1751   2416130                1
# ..            ...       ...              ...
# 911          2018   2278414               10
# 912          2018   2278415               10
# 913          1908   2278414               10
# 914          1908   2278415               10
# 915          8433   2278415               10
#
#                               from_station_id  to_stop_id  \
# 0    9e23e8f481e69e44a5d39b27f4f664061aa934f7        2067
# 1    9e23e8f481e69e44a5d39b27f4f664061aa934f7        1832
# 2    5b02b0e7ad4f13515b5b21e41413a312bb3a1656        1725
# 3    4b8233fad181fd35e2999083df9010dc57b30b3e        1751
# 4    3784adacc9a6d443571a3b9701c84ee987710823        1832
# ..                                        ...         ...
# 911  c3e0633bc8abcbd5f4b5fa674ea4a4f015ceaad6        1908
# 912  c3e0633bc8abcbd5f4b5fa674ea4a4f015ceaad6        1908
# 913  472fe5b84e856bbef75af57174a2c080d15c3de0        1952
# 914  472fe5b84e856bbef75af57174a2c080d15c3de0        1952
# 915  c6d47074acd46aeeecadff1d372279a9482154c7        1817
#
#                                 to_station_id  mean_transfer_time
# 0    5b02b0e7ad4f13515b5b21e41413a312bb3a1656                  79
# 1    135c7e55f428deec34db86894ff054ab0a22900a                 300
# 2    4b8233fad181fd35e2999083df9010dc57b30b3e                  73
# 3    3784adacc9a6d443571a3b9701c84ee987710823                 108
# 4    135c7e55f428deec34db86894ff054ab0a22900a                  98
# ..                                        ...                 ...
# 911  472fe5b84e856bbef75af57174a2c080d15c3de0                  70
# 912  472fe5b84e856bbef75af57174a2c080d15c3de0                  70
# 913  92b9bb5007dec1d038f09121dfaffc7e3f05da2b                 170
# 914  92b9bb5007dec1d038f09121dfaffc7e3f05da2b                 170
# 915  54db0cc8fda0a553b4bd654edb1c5d64099d0a08                 110
#
# [916 rows x 7 columns]

# %% [markdown]
# ## Format with Jinja into Neo4J Cypher

# %%
stations_df.head(2).to_dict('records')
# Out:
# [{'index': 0,
#   'name': 'Olympiades',
#   'lat': 48.82694828196075,
#   'lon': 2.367038433387592,
#   'station_id': 'c013a983778accb3494ea2b6e2d62d9b364f53f6',
#   'lines': ['14']},
#  {'index': 1,
#   'name': 'Bibliothèque-François Mitterrand',
#   'lat': 48.82983069527111,
#   'lon': 2.3761200093448367,
#   'station_id': 'e799ff89f02653528c8660989938659f86e200ec',
#   'lines': ['14']}]

# %%
def _tpl(df, name: Template):
    return df.apply(lambda r: name.render(r.to_dict()), axis='columns').str.cat(sep=',\n')

_station_nodes_tpl = Template('''\
  (STATION_{{ station_id }}:Station { name: "{{ name }}", latitude: {{ lat }}, longitude: {{ lon }}, lines: {{ lines }} })
''')

_stop_nodes_tpl = Template('''\
  (STOP_{{ stop_id }}:Stop { name: "{{ name }}", stop_id: "{{ stop_id }}" })
''')

_stop_station_relationships_tpl = Template('''\
  (STOP_{{ stop_id }})-[:LOCATED]->(STATION_{{ station_id }})
''')

_travel_relationships_tpl = Template('''\
  (STOP_{{ from_stop_id }})-[:TRAVEL_TO { line: "{{ route_short_name }}", transfer_time: {{ mean_transfer_time }} }]->(STOP_{{ to_stop_id }})
''')

_transfer_relationships_tpl = Template('''\
  (STOP_{{ from_stop_id }})-[:TRANSFER { transfer_time: {{ min_transfer_time }} }]->(STOP_{{ to_stop_id }})
''')


CYPHER_TEMPLATE = '''\
// Based on https://dataratp.opendatasoft.com/explore/dataset/offre-transport-de-la-ratp-format-gtfs/information/

// ============
// NODES
// ============

// Create Stations
CREATE
{{ stations }}

// Create Stops
CREATE
{{ stops }}

// ============
// RELATIONS
// ============

// Create Stop stations
CREATE 
{{ stop_stations }}

// Create Travels
CREATE 
{{ travels }}

// Create Transfers
CREATE 
{{ transfers }}
'''

Template(CYPHER_TEMPLATE). \
    stream(
        stations=_tpl(stations_df, _station_nodes_tpl),
        stops=_tpl(stops_df, _stop_nodes_tpl),
        travels=_tpl(travels_df, _travel_relationships_tpl),
        transfers=_tpl(transfers_df, _transfer_relationships_tpl),
        stop_stations=_tpl(stops_df, _stop_station_relationships_tpl),
    ). \
    dump(OUTPUT_FILE)

# Show result
with open(OUTPUT_FILE) as fd:
    content = fd.read()
    print(content)
# Out:
# // Based on https://dataratp.opendatasoft.com/explore/dataset/offre-transport-de-la-ratp-format-gtfs/information/
#
# // ============
# // NODES
# // ============
#
# // Create Stations
# CREATE
#   (STATION_c013a983778accb3494ea2b6e2d62d9b364f53f6:Station { name: "Olympiades", latitude: 48.82694828196075, longitude: 2.367038433387592, lines: ['14'] }),
#   (STATION_e799ff89f02653528c8660989938659f86e200ec:Station { name: "Bibliothèque-François Mitterrand", latitude: 48.82983069527111, longitude: 2.3761200093448367, lines: ['14'] }),
#   (STATION_757558be993d3632918145952a6b1e785d75c347:Station { name: "Cour Saint-Emilion", latitude: 48.83352086080552, longitude: 2.3862652367404573, lines: ['14'] }),
#   (STATION_51cac4e9016ad7dc7f036283af508252b245b360:Station { name: "Bercy", latitude: 48.84054278296546, longitude: 2.3794094631230687, lines: ['14', '6'] }),
#   (STATION_49541b7895349f795ad38c3b7fc249aec6b490b7:Station { name: "Gare de Lyon", latitude: 48.84465215098295, longitude: 2.3731081475452798, lines: ['14', '1'] }),
#   (STATION_ae9c8e1611f553fd7dc21d399dc4161a788ca201:Station { name: "Châtelet", latitude: 48.85895618133368, longitude: 2.3473612552142624, lines: ['14', '4', '11', '7', '1'] }),
#   (STATION_3f6701fa5352e7df067b97a9ae7c9131d57f6472:Station { name: "Madeleine", latitude: 48.869578970578424, longitude: 2.324162488791942, lines: ['14', '12', '8'] }),
#   (STATION_9312306d63bb3b64ed9d6092ec90f7c194d27a93:Station { name: "Saint-Lazare", latitude: 48.8755376703957, longitude: 2.325196489977428, lines: ['14', '3', '12', '13'] }),
#   (STATION_f85e6dfb1bc7fad3573a86527a6e1f6f49662be4:Station { name: "Saint-Denis-Université", latitude: 48.94611087248738, longitude: 2.3620451929905992, lines: ['13'] }),
#   (STATION_33a3c8c64eb4fe122a6a0e3ee083ac2018576639:Station { name: "Villiers", latitude: 48.88132429394469, longitude: 2.316596761508817, lines: ['2', '3'] }),
#   (STATION_8a19b53f6a6f746889098bfb4fb97b78c35c3619:Station { name: "Volontaires", latitude: 48.84141844267774, longitude: 2.307993649386661, lines: ['12'] }),
#   (STATION_bb8161eae67c1eeb157b70a5969c13e1bd267742:Station { name: "Voltaire (Léon Blum)", latitude: 48.85766372576006, longitude: 2.3800362967955064, lines: ['9'] }),
#   (STATION_6cd59adc90d85db5648989f4356a751cf5285080:Station { name: "Wagram", latitude: 48.88371247603735, longitude: 2.305557757514304, lines: ['3'] }),
#   (STATION_2557ea75d3aacd6621d0d3a44237da5253cc38ed:Station { name: "Danube", latitude: 48.88195101817821, longitude: 2.393260675857388, lines: ['7B'] }),
#   (STATION_b516d76d1f05353aa41ade39dcf85ad2f320abd7:Station { name: "Trocadéro", latitude: 48.8630891350352, longitude: 2.2868403784945937, lines: ['9', '6'] }),
#   (STATION_3c0ee6000ba3ac0254e7b4ba95f1cfe5fec38ed3:Station { name: "Varenne", latitude: 48.85639306919847, longitude: 2.3147543648102884, lines: ['13'] }),
#   (STATION_d69f5a5ca2429ca0144b366f445c5732ecf7d90f:Station { name: "Villejuif-Léo Lagrange", latitude: 48.80376966328267, longitude: 2.3639093063890435, lines: ['7'] }),
#   (STATION_0e04a7b862645c815e1c8fcfa9fe2a7f9b1a6301:Station { name: "Saint-Jacques", latitude: 48.83299169177581, longitude: 2.3366828966443496, lines: ['6'] }),
#   (STATION_cd5f83ffeb89864fb6e54f09e6fc8b7c2ac1da97:Station { name: "Saint-Marcel", latitude: 48.838516743515164, longitude: 2.360727550361784, lines: ['5'] }),
#   (STATION_b6b45b690c4b21c6bb8307800c7603cff8cdb776:Station { name: "Saint-Paul (Le Marais)", latitude: 48.85513451823503, longitude: 2.3613343390676635, lines: ['1'] }),
#   (STATION_49d2ba613fc8dae0a7e23d9e3d449c66339fb9d5:Station { name: "Quai de la Gare", latitude: 48.83761467578531, longitude: 2.373852115680497, lines: ['6'] }),
#   (STATION_2dec17b2533a55b48bd326dec899258a95051e61:Station { name: "Raspail", latitude: 48.83915698149679, longitude: 2.330474151162931, lines: ['4', '6'] }),
#   (STATION_ff840e2ba5c9624d68fc3914acfd24ab1220804e:Station { name: "Rennes", latitude: 48.84819826882478, longitude: 2.3280217486281134, lines: ['12'] }),
#   (STATION_af142c505ee2d0bad5e2c6271ca6aebe08cba573:Station { name: "République", latitude: 48.86741082883539, longitude: 2.363587825558049, lines: ['9', '3', '5', '8', '11'] }),
#   (STATION_4d432c04d00a77f4e46c796336e452d2cadc2d29:Station { name: "Place d'Italie", latitude: 48.83155230264314, longitude: 2.3553334432190454, lines: ['7', '5', '6'] }),
#   (STATION_8f32708f85ebbd4f293aafb6be48b8ca0f22cab3:Station { name: "Place Monge (Jardin des Plantes)", latitude: 48.84316469276683, longitude: 2.3521103624150967, lines: ['7'] }),
#   (STATION_135c7e55f428deec34db86894ff054ab0a22900a:Station { name: "Nation", latitude: 48.849010153648216, longitude: 2.3976646127910075, lines: ['9', '1', '2', '6'] }),
#   (STATION_05835fa7ddf69308b8c10d609b1dcbf0b67430e8:Station { name: "Odéon", latitude: 48.85231488119486, longitude: 2.338861720336335, lines: ['10', '4'] }),
#   (STATION_b04319f5646b245a58b13643d7756fc7b2517c44:Station { name: "Marcadet-Poissonniers", latitude: 48.89154393063056, longitude: 2.3493711153819112, lines: ['4', '12'] }),
#   (STATION_14e4b73bf6dd8dac0b4c6b914d23530cd764c5c0:Station { name: "La Fourche", latitude: 48.8874368425293, longitude: 2.3257252220174083, lines: ['13'] }),
#   (STATION_b6b5207941494f842427f450222696841d127e27:Station { name: "La Motte-Picquet-Grenelle", latitude: 48.849018928349764, longitude: 2.297762160707931, lines: ['6', '10', '8'] }),
#   (STATION_9e8f24d2b9230a8ad406e60848292b372bab6cfb:Station { name: "Gambetta", latitude: 48.86503429801815, longitude: 2.3985414869122423, lines: ['3B', '3'] }),
#   (STATION_5e4fb6214167ea94e8afe383cfd57dbcf18b9722:Station { name: "Ségur", latitude: 48.84686470206919, longitude: 2.307268847578926, lines: ['10'] }),
#   (STATION_9f10bdf91d7a21d24f2a8dd77570d01a1188e8aa:Station { name: "Les Agnettes", latitude: 48.922916331509064, longitude: 2.2859638965766345, lines: ['13'] }),
#   (STATION_c8937f2a3245254854b8ef3a9c227b1a9d14a14a:Station { name: "Asnières-Gennevilliers Les Courtilles", latitude: 48.93029362287076, longitude: 2.2837606331952487, lines: ['13'] }),
#   (STATION_1fb6f3c545203072c5be825075d49896bf302aca:Station { name: "Sentier", latitude: 48.867350381431294, longitude: 2.3475672354150805, lines: ['3'] }),
#   (STATION_7f48726ea6fa81e5958be150611d249e61083bcf:Station { name: "Sèvres-Lecourbe", latitude: 48.84499615085685, longitude: 2.3108648300441543, lines: ['6'] }),
#   (STATION_a3a185d99d3735885b77577f2c41be658fd49534:Station { name: "Sèvres-Babylone", latitude: 48.850939288430745, longitude: 2.3261146548222844, lines: ['10', '12'] }),
#   (STATION_4af08044681cda57876ea423859933efce163214:Station { name: "Simplon", latitude: 48.89404255451658, longitude: 2.3473135785509056, lines: ['4'] }),
#   (STATION_9ac4ecb40e5d8a62f99132b4c280c8f23ae65efa:Station { name: "Solférino", latitude: 48.858533359508236, longitude: 2.323089248787209, lines: ['12'] }),
#   (STATION_c2eb9b8d2e7f1b41bba03bacf141ea475bb5da14:Station { name: "Stalingrad", latitude: 48.884189294208774, longitude: 2.367030441974567, lines: ['2', '5', '7'] }),
#   (STATION_150648daadb38ea1c0c9317856f27f8a7901bb5d:Station { name: "Strasbourg-Saint-Denis", latitude: 48.869632365187464, longitude: 2.35450206308924, lines: ['4', '9', '8'] }),
#   (STATION_441976106fbad10b996482e590ff5480c292b23b:Station { name: "Sully-Morland", latitude: 48.85079359474211, longitude: 2.3612369937142983, lines: ['7'] }),
#   (STATION_76c559967c15c4a75cafb654f8ce28267189f5cb:Station { name: "Télégraphe", latitude: 48.87552244924565, longitude: 2.3986765111449517, lines: ['11'] }),
#   (STATION_5e83789be88ee4a74db3912e093343ff83d996ae:Station { name: "Temple", latitude: 48.86676416781452, longitude: 2.361571327032732, lines: ['3'] }),
#   (STATION_0d3cb42dcb79ef660f3224e271e9fdbc6ed40f68:Station { name: "Ternes", latitude: 48.87822804050767, longitude: 2.2981214325821844, lines: ['2'] }),
#   (STATION_e77bcb25cad2c019da45e9210ced099b1e4dd2e3:Station { name: "Tolbiac", latitude: 48.82615945391136, longitude: 2.3570194661891253, lines: ['7'] }),
#   (STATION_2b44ec3ecb1f4e409fed9f1d9b44c5acde433d8d:Station { name: "Trinité-d'Estienne d'Orves", latitude: 48.87632903743871, longitude: 2.3318045685105955, lines: ['12'] }),
#   (STATION_3301b737f2e3f15b76069dcccdfec1fa868f6645:Station { name: "Tuileries", latitude: 48.864780162500075, longitude: 2.3290949544294275, lines: ['1'] }),
#   (STATION_34b5d5f91fbaa0f006cacdb27c196f8ec13267bd:Station { name: "Vaneau", latitude: 48.84870084962003, longitude: 2.321239881938573, lines: ['10'] }),
#   (STATION_0ad4e2bb3936d47bbbdaf01321ba978f55ef753c:Station { name: "Vaugirard (Adolphe Chérioux)", latitude: 48.83943928123955, longitude: 2.301078042473925, lines: ['12'] }),
#   (STATION_df3ec0b8b63b7b2bb0b13287a90922d08845369e:Station { name: "Carrefour-Pleyel", latitude: 48.919943505083396, longitude: 2.3439094197858905, lines: ['13'] }),
#   (STATION_482041ea624aebe90511d166a4018c83104f9e96:Station { name: "Vavin", latitude: 48.84205985758204, longitude: 2.328867050437212, lines: ['4'] }),
#   (STATION_0bc418a62f163286b91c169bcad8e4ebd927f0ed:Station { name: "Victor Hugo", latitude: 48.869864912484076, longitude: 2.285226207250439, lines: ['2'] }),
#   (STATION_18ed16a48a40244962b56ff8fe60b85f83b1de21:Station { name: "Villejuif-Louis Aragon", latitude: 48.78663801111984, longitude: 2.367110527381649, lines: ['7'] }),
#   (STATION_2d4f4c7ac2540d3b36443f937c3389786619f09f:Station { name: "Villejuif-Paul Vaillant Couturier (Hôpital Paul Brousse)", latitude: 48.79599413239317, longitude: 2.3682314519156806, lines: ['7'] }),
#   (STATION_1d65bce2890e769666541df18168d8c0a4dcb72a:Station { name: "Reuilly-Diderot", latitude: 48.8473528769588, longitude: 2.3858425400402448, lines: ['1', '8'] }),
#   (STATION_020cf4f9196d80a0595bfbb8ffedd605694129fa:Station { name: "Richard-Lenoir", latitude: 48.86048841284578, longitude: 2.37192043750214, lines: ['5'] }),
#   (STATION_538762da2a4bc4f5d6c6d4b580782f3760061b4c:Station { name: "Richelieu-Drouot", latitude: 48.87209612378978, longitude: 2.339325555856426, lines: ['9', '8'] }),
#   (STATION_c63baf469d11783c1de913b00783ce54fe76ca28:Station { name: "Riquet", latitude: 48.88839323190129, longitude: 2.374433108884994, lines: ['7'] }),
#   (STATION_0d1e3b29bde6925b15f49071376b6857976955df:Station { name: "Robespierre", latitude: 48.85568080819694, longitude: 2.423659085483019, lines: ['9'] }),
#   (STATION_da7705caa15608fea217326726ec6ed97a9c6c9d:Station { name: "Rome", latitude: 48.882070833937036, longitude: 2.3203983393099863, lines: ['2'] }),
#   (STATION_fd4cd8df9fd82891e8bd3d367005188700630b65:Station { name: "Rue de la Pompe (Avenue Georges Mandel)", latitude: 48.864253384403426, longitude: 2.277916762028845, lines: ['9'] }),
#   (STATION_a07d291936e8c52023a1a11d3d2327e160f790a2:Station { name: "Rue des Boulets", latitude: 48.8522227131835, longitude: 2.3891156509271867, lines: ['9'] }),
#   (STATION_e4140cc2faf575adc54381288643fe410085ff3d:Station { name: "Rue du Bac", latitude: 48.85589133781551, longitude: 2.325704993899314, lines: ['12'] }),
#   (STATION_e95a628a3b4019fb6fe5874171bdceac0cc56e8e:Station { name: "Grands Boulevards", latitude: 48.87151181707817, longitude: 2.3432083775448653, lines: ['9', '8'] }),
#   (STATION_576324a25f890dec93f2832903e1c61c444523a9:Station { name: "Saint-Ambroise", latitude: 48.86164742429928, longitude: 2.3731471407723035, lines: ['9'] }),
#   (STATION_2d96771baf808650651f1490807f1d019f42330f:Station { name: "Saint-Augustin", latitude: 48.87438676021276, longitude: 2.3207278319647315, lines: ['9'] }),
#   (STATION_c3b0be264f4c3c4ef211bf71c2b44ce3af6a6e2d:Station { name: "Basilique de Saint-Denis", latitude: 48.936477492650496, longitude: 2.3596397453045825, lines: ['13'] }),
#   (STATION_cbbeaf93be2f7a03f9b527ff3d53a53605674f36:Station { name: "Saint-Denis - Porte de Paris", latitude: 48.929926665270926, longitude: 2.3561861491888694, lines: ['13'] }),
#   (STATION_73706d1b15796b5b8dfc96b184f5bcf232009499:Station { name: "Saint-Fargeau", latitude: 48.871699810971116, longitude: 2.4042987242021825, lines: ['3B'] }),
#   (STATION_11427f1f181af422444ced363f78385893856704:Station { name: "Saint-François-Xavier", latitude: 48.85098255982351, longitude: 2.31442986460027, lines: ['13'] }),
#   (STATION_0b5d9b23d02d10b48b43bc853a13b930cb6c1c5f:Station { name: "Saint-Georges", latitude: 48.87859395523621, longitude: 2.3378269689170192, lines: ['12'] }),
#   (STATION_00c1a355adb7565618bafc62393f74c6952de830:Station { name: "Saint-Germain des Prés", latitude: 48.853447237738344, longitude: 2.3330463260448666, lines: ['4'] }),
#   (STATION_4b8233fad181fd35e2999083df9010dc57b30b3e:Station { name: "Saint-Mandé", latitude: 48.84623825662077, longitude: 2.4189998281092557, lines: ['1'] }),
#   (STATION_f6b5055912f494b9f5674ea99474637b99c650ec:Station { name: "Rue Saint-Maur", latitude: 48.86408940574645, longitude: 2.3808997885521195, lines: ['3'] }),
#   (STATION_909b39a4c1ae826acd57d07ab7b105ad1f08598b:Station { name: "Saint-Michel", latitude: 48.85359990788579, longitude: 2.3439962410940125, lines: ['4'] }),
#   (STATION_5d843fe10e0bea0f74fb74957e986f0f647dcab6:Station { name: "Saint-Philippe du Roule", latitude: 48.872470665793706, longitude: 2.310769101230354, lines: ['9'] }),
#   (STATION_768416cc61241754678d747f3365899e21b523c7:Station { name: "Saint-Placide", latitude: 48.84701184016864, longitude: 2.327055111355132, lines: ['4'] }),
#   (STATION_dd976375cf790864b5bf5638fda1c480c6c87c45:Station { name: "Saint-Sulpice", latitude: 48.8511463550549, longitude: 2.3309628563664644, lines: ['4'] }),
#   (STATION_28a2bfceac0d8d24452ec00b37a8d8ebddd261c8:Station { name: "Porte d'Ivry", latitude: 48.82135736230755, longitude: 2.3693082372232483, lines: ['7'] }),
#   (STATION_098b59cba87706ba3ed819d0119b59914016f358:Station { name: "Porte d'Orléans (Général Leclerc)", latitude: 48.822817060234954, longitude: 2.325072625148001, lines: ['4'] }),
#   (STATION_2f06223e400bf72e01ac1e982dd95095441a2cbf:Station { name: "Porte Dauphine (Maréchal de Lattre de Tassigny)", latitude: 48.871792216417504, longitude: 2.27486996119569, lines: ['2'] }),
#   (STATION_7c77047488a2c809e977edf51ea31377158687b5:Station { name: "Porte de Bagnolet", latitude: 48.864336535483645, longitude: 2.4088253760377283, lines: ['3'] }),
#   (STATION_6a1c3015071dab88f018d0a6122ff709fdca0641:Station { name: "Porte de Champerret", latitude: 48.88573915969202, longitude: 2.2918606206755348, lines: ['3'] }),
#   (STATION_0c0172b7ca11d91402dfde5a3c0a2562bdfe2779:Station { name: "Porte de Choisy", latitude: 48.81990244616168, longitude: 2.364965598290819, lines: ['7'] }),
#   (STATION_473998bdf3502ebb6141851f4e1b41bf351df94a:Station { name: "Porte de Clichy", latitude: 48.894436060297956, longitude: 2.313565665465226, lines: ['13'] }),
#   (STATION_f3b96112ed5dbed74b7071785aac57b7e1243a74:Station { name: "Porte de Clignancourt", latitude: 48.89797017040717, longitude: 2.3439883834332904, lines: ['4'] }),
#   (STATION_f36b996d066d7ccd63bd06173068589e7cf88f2f:Station { name: "Porte de la Chapelle", latitude: 48.897959343241475, longitude: 2.3592550695796524, lines: ['12'] }),
#   (STATION_d80d1e1ab60fa85b408c6f256c4aab5a07b4c859:Station { name: "Porte de la Villette", latitude: 48.89752915689145, longitude: 2.3856442301273044, lines: ['7'] }),
#   (STATION_3e6e3ce2dd4e36a3000bae12456dbc8e341fbd8e:Station { name: "Porte de Montreuil", latitude: 48.853379877813815, longitude: 2.4104581874163533, lines: ['9'] }),
#   (STATION_cc88609ab65bbae963dbba8b5cc37ef75899c0ae:Station { name: "Porte de Pantin", latitude: 48.8885839809719, longitude: 2.392422875718541, lines: ['5'] }),
#   (STATION_56a2e8b404322bae30ad40232691a9062ace5ea9:Station { name: "Porte de Saint-Cloud", latitude: 48.83756533447362, longitude: 2.255591274447898, lines: ['9'] }),
#   (STATION_132667af3ed97f02df8e56048538d8bf3f305df7:Station { name: "Porte de Saint-Ouen", latitude: 48.89751173277147, longitude: 2.329021647212208, lines: ['13'] }),
#   (STATION_f31191a7a16c101ab3586b8fea08cdeaba6415dd:Station { name: "Porte de Vanves", latitude: 48.82776532658967, longitude: 2.3043123507630607, lines: ['13'] }),
#   (STATION_7932a2f956cae804adfcf4dbe602422bc7a293b1:Station { name: "Porte de Versailles", latitude: 48.83225345274901, longitude: 2.287864137819189, lines: ['12'] }),
#   (STATION_3784adacc9a6d443571a3b9701c84ee987710823:Station { name: "Porte de Vincennes", latitude: 48.84701651841913, longitude: 2.4108168823347644, lines: ['1'] }),
#   (STATION_14e669cbc94012ba8c6ec441cf9f0da5379eedd2:Station { name: "Porte des Lilas", latitude: 48.8769382235089, longitude: 2.4063765669297816, lines: ['3B', '11'] }),
#   (STATION_77420c9d99ce91b7c30a8d65eba6a4ebf2031f34:Station { name: "Porte Maillot", latitude: 48.878006176278994, longitude: 2.282465640001333, lines: ['1'] }),
#   (STATION_d98eba9f136364c2215b6fcdfb59a2f0e8ab5618:Station { name: "Pré-Saint-Gervais", latitude: 48.880159932112406, longitude: 2.3985866218697662, lines: ['7B'] }),
#   (STATION_deb7f2f96013ec315ad7dbeea2a2b9b64cfac026:Station { name: "Pyramides", latitude: 48.866496987038545, longitude: 2.3340942152590967, lines: ['7', '14'] }),
#   (STATION_3572758f962416168fad8aa7f97b7917087de0a7:Station { name: "Pyrénées", latitude: 48.87382117233675, longitude: 2.3848863721979034, lines: ['11'] }),
#   (STATION_a20358b42120a8330ba4f8ea671a02926cca7eb2:Station { name: "Quai de la Rapée", latitude: 48.84596603240645, longitude: 2.366913179738312, lines: ['5'] }),
#   (STATION_dbcf9c7d58f3a1b9197882e19ea96b02b640e217:Station { name: "Quatre Septembre", latitude: 48.86966057219203, longitude: 2.3363282816417112, lines: ['3'] }),
#   (STATION_c3e2adfac7303510574b467e70a9c3d0fbf0d976:Station { name: "Rambuteau", latitude: 48.861193395641635, longitude: 2.3532869598707133, lines: ['11'] }),
#   (STATION_1eaca422810805ff728760a6833a2c5f2e4734e3:Station { name: "Ranelagh", latitude: 48.855504403001994, longitude: 2.2699591782557653, lines: ['9'] }),
#   (STATION_ce31c6c92df0be368b97fc445c553d40297260b2:Station { name: "Réaumur-Sébastopol", latitude: 48.86604666963103, longitude: 2.3526209540151863, lines: ['4', '3'] }),
#   (STATION_844fcdb03e0f28f6509db0e13d52157a0299dfc5:Station { name: "Ourcq", latitude: 48.886923877470686, longitude: 2.386656434403456, lines: ['5'] }),
#   (STATION_b73242030b9ef5c1aefaf1cf2fa2df03a52d8c86:Station { name: "Palais-Royal (Musée du Louvre)", latitude: 48.8623718215243, longitude: 2.3365736007364304, lines: ['1', '7'] }),
#   (STATION_cc37d07a06d8b5dfc30034e61d35c68938e4ab0f:Station { name: "Parmentier", latitude: 48.865259856673156, longitude: 2.374757081716768, lines: ['3'] }),
#   (STATION_986ae476bf49f90002563db07d83608b2d7fff3b:Station { name: "Passy", latitude: 48.85753438251388, longitude: 2.28559270581709, lines: ['6'] }),
#   (STATION_3543c58f7b39aff6e251d02bc79d1b2941fe7e51:Station { name: "Pasteur", latitude: 48.8420128040577, longitude: 2.31329004383549, lines: ['6', '12'] }),
#   (STATION_ef22def1e0f67a706561f8e0f5398c27122776bb:Station { name: "Pelleport", latitude: 48.86822334760735, longitude: 2.4013243805441022, lines: ['3B'] }),
#   (STATION_d7c9917b7cabda8f4137b5380c24dc92a2ebf745:Station { name: "Père-Lachaise", latitude: 48.86316120506396, longitude: 2.3872604001843536, lines: ['2', '3'] }),
#   (STATION_88b31f5d803e3468f7151f66046e46e6a3879250:Station { name: "Pereire", latitude: 48.885031061253606, longitude: 2.2971351115061647, lines: ['3'] }),
#   (STATION_24be7fcc6f129019d77e7b5353d12f2e972d792c:Station { name: "Pernety", latitude: 48.83393381981092, longitude: 2.3179089721632797, lines: ['13'] }),
#   (STATION_a56eb559aaafe6f08a004e536089188f5c12b9e5:Station { name: "Philippe Auguste", latitude: 48.858378841469936, longitude: 2.3897347327397043, lines: ['2'] }),
#   (STATION_570eabb704a31ae10cf7e9f8ead4769edd462e39:Station { name: "Picpus", latitude: 48.845323114613954, longitude: 2.4017863137606863, lines: ['6'] }),
#   (STATION_89f7c24f9c5b0e22216468bed1a2fde6db7c4c6f:Station { name: "Pierre et Marie Curie", latitude: 48.81591718160038, longitude: 2.377878816483871, lines: ['7'] }),
#   (STATION_53c25188bf0d012784dd5e2bc09a071900688e41:Station { name: "Pigalle", latitude: 48.88242252841757, longitude: 2.3372546821015354, lines: ['2', '12'] }),
#   (STATION_e260b3df611a73c2da2d26ae04b822fd51a1ae99:Station { name: "Place de Clichy", latitude: 48.88345565159549, longitude: 2.327374993410356, lines: ['2', '13'] }),
#   (STATION_ff5089e9bb8b85a6a6a4388a0ddb562277ed3a4f:Station { name: "Place des Fêtes", latitude: 48.8772239477293, longitude: 2.392765050250897, lines: ['7B', '11'] }),
#   (STATION_1d7ce1fa97185f141f721374caadf15862b07046:Station { name: "Plaisance", latitude: 48.8317580937884, longitude: 2.3138665498481625, lines: ['13'] }),
#   (STATION_f88d48afadd0f7fbafd27a5715dd03afc88b6f27:Station { name: "Poissonnière", latitude: 48.87735309528802, longitude: 2.349381423952599, lines: ['7'] }),
#   (STATION_342b985d9d70f76d8797fd6a6bb64ad53585af22:Station { name: "Pont de Levallois-Bécon", latitude: 48.89730990517954, longitude: 2.2807686428069003, lines: ['3'] }),
#   (STATION_130ec6545c55c01362cc38cb7bf9874cc04ee3b3:Station { name: "Pont de Neuilly", latitude: 48.88550610941815, longitude: 2.258527470197358, lines: ['1'] }),
#   (STATION_cdd2e3828b73cd059cda8df7c1f140e1d558ac01:Station { name: "Pont de Sèvres", latitude: 48.829690338022736, longitude: 2.2305284341923346, lines: ['9'] }),
#   (STATION_bfa91a3dfc5e6d88c04a852c5fc6fd7920578790:Station { name: "Pont Marie (Cité des Arts)", latitude: 48.85346358569476, longitude: 2.357383972809163, lines: ['7'] }),
#   (STATION_50ee676d7aed0c0f2364ae27a0cd13ab58453054:Station { name: "Pont Neuf", latitude: 48.85853410228574, longitude: 2.3421172386659985, lines: ['7'] }),
#   (STATION_781b3d995bbdc86fe37dd20828aaec4380af5574:Station { name: "Porte d'Italie", latitude: 48.8187170251155, longitude: 2.3605008328053656, lines: ['7'] }),
#   (STATION_98fe71a65b79c48c151ceaedb0f1e202efda5896:Station { name: "Maubert-Mutualité", latitude: 48.849716940163574, longitude: 2.348925558491872, lines: ['10'] }),
#   (STATION_d135a1d75654bf3478baa7c29091c4e620841bba:Station { name: "Ménilmontant", latitude: 48.86570578762299, longitude: 2.3844293751632057, lines: ['2'] }),
#   (STATION_2e8e56e06b70b01827bedcfa268d1af24dc79273:Station { name: "Michel-Ange-Auteuil", latitude: 48.84792459278511, longitude: 2.2642359057824177, lines: ['9', '10'] }),
#   (STATION_54db0cc8fda0a553b4bd654edb1c5d64099d0a08:Station { name: "Michel-Ange-Molitor", latitude: 48.845056129032, longitude: 2.261911423279769, lines: ['9', '10'] }),
#   (STATION_8afe4fe592442d32367cd3d3d0882bb0c87a1fed:Station { name: "Mirabeau", latitude: 48.84708485890486, longitude: 2.2730749149220117, lines: ['10'] }),
#   (STATION_b12928e15cc18a394640eb5a6f0ded55793f0434:Station { name: "Miromesnil", latitude: 48.87353214061607, longitude: 2.315578024866189, lines: ['9', '13'] }),
#   (STATION_54c0c0dad75acc1cbd934f656130cabdf681a2f6:Station { name: "Monceau", latitude: 48.88057689074842, longitude: 2.309415946164807, lines: ['2'] }),
#   (STATION_901b736c6d3a83f22020473ed860882e207547f8:Station { name: "Montparnasse-Bienvenue", latitude: 48.844189508526796, longitude: 2.3244412324337014, lines: ['4', '6', '12', '13'] }),
#   (STATION_989b08af010f69e008243ce94f31dc3105efe557:Station { name: "Mouton-Duvernet", latitude: 48.832191599269656, longitude: 2.3304069926293205, lines: ['4'] }),
#   (STATION_a39ebdd600497c77fe460ef044c14d678207d936:Station { name: "Nationale", latitude: 48.83288128867883, longitude: 2.361909408016197, lines: ['6'] }),
#   (STATION_b964e2801c3b68faca1a6950bd9e60e74f03509f:Station { name: "Notre-Dame de Lorette", latitude: 48.876050554237366, longitude: 2.337908692037609, lines: ['12'] }),
#   (STATION_ab9979a244e559ed6fef67d40d33441a487158ea:Station { name: "Notre-Dame des Champs", latitude: 48.84478304833005, longitude: 2.3284444832927207, lines: ['12'] }),
#   (STATION_14d830bd356c029c535374b94095ebd3a9128f6c:Station { name: "Oberkampf", latitude: 48.864902415940435, longitude: 2.367537013481096, lines: ['5', '9'] }),
#   (STATION_5e96dd0cde47a24f2968e73afbca469e921103db:Station { name: "Opéra", latitude: 48.87072097629208, longitude: 2.3322547435729586, lines: ['3', '7', '8'] }),
#   (STATION_bacf883977d68ab8a0de7db23ba8de23f3d4a4ab:Station { name: "Le Peletier", latitude: 48.87496305802611, longitude: 2.3401567908492056, lines: ['7'] }),
#   (STATION_b3d17cda06d8f7a0525ab1445318abdf6e48af04:Station { name: "Les Gobelins", latitude: 48.836127439752524, longitude: 2.3520811178355734, lines: ['7'] }),
#   (STATION_cd18696c308f68d44eb49dc5e4181b884b8289b9:Station { name: "Les Halles", latitude: 48.86201197072052, longitude: 2.3464764519062062, lines: ['4'] }),
#   (STATION_17819a2e9d5491f24920758cec854d26d9c16219:Station { name: "Les Sablons (Jardin d'acclimatation)", latitude: 48.88129918549113, longitude: 2.271915176017792, lines: ['1'] }),
#   (STATION_fd131cce7945f5754c9e954a5245a8b56aed2848:Station { name: "Liège", latitude: 48.87953716638083, longitude: 2.3268579472729614, lines: ['13'] }),
#   (STATION_7ce16da58ee3c27df41099e927f47ebd1d632339:Station { name: "Louis Blanc", latitude: 48.880900428151094, longitude: 2.365107218264337, lines: ['7', '7B'] }),
#   (STATION_280ae6e235dd335985ecda912b0581e5c4c3151b:Station { name: "Louise Michel", latitude: 48.889269622246026, longitude: 2.288055124803904, lines: ['3'] }),
#   (STATION_ae7b5aa8f1d7372c6434887705f4c90a2c64d616:Station { name: "Louvre-Rivoli", latitude: 48.860879857593744, longitude: 2.340973275817903, lines: ['1'] }),
#   (STATION_b5931d0271c25b63cdebbf453dae9423ce746f31:Station { name: "Mabillon", latitude: 48.852845133654455, longitude: 2.3351437185160684, lines: ['10'] }),
#   (STATION_c8ede457822a25b243719948f95a3288adea2107:Station { name: "Mairie d'Issy", latitude: 48.82434652601842, longitude: 2.2735658296006465, lines: ['12'] }),
#   (STATION_8dc69295975ab31c3511dcb4190046ab4424e671:Station { name: "Mairie d'Ivry", latitude: 48.81121453549021, longitude: 2.383508928732683, lines: ['7'] }),
#   (STATION_3239f141f3f57eb1e0db0d3015e7fb5ed34a1560:Station { name: "Mairie de Clichy", latitude: 48.90400543242958, longitude: 2.3053681208668606, lines: ['13'] }),
#   (STATION_6c191ea45512ce1243e63f12cbcc1db0b337ce24:Station { name: "Mairie de Montreuil", latitude: 48.862280986338995, longitude: 2.4418276791277127, lines: ['9'] }),
#   (STATION_3d0e0a973ab34b287cda757f58934563798f0c14:Station { name: "Mairie de Saint-Ouen", latitude: 48.911621680383824, longitude: 2.333736964842092, lines: ['13'] }),
#   (STATION_67b879a0a6f06bd46446c83ef314c50f0922ea03:Station { name: "Mairie des Lilas", latitude: 48.88005106177268, longitude: 2.415660206064229, lines: ['11'] }),
#   (STATION_b164058e42cd50a715d8cb5288427e26d167e00c:Station { name: "Maison Blanche", latitude: 48.82287877506322, longitude: 2.358079894290851, lines: ['7'] }),
#   (STATION_9e36567ac85af67159e7a9e0c4bea14635c62697:Station { name: "Malakoff-Plateau de Vanves", latitude: 48.8224426939998, longitude: 2.2979321053287274, lines: ['13'] }),
#   (STATION_704fb4cb681b226b4d5c64d514c5898fd518d2a9:Station { name: "Malakoff-Rue Etienne Dolet", latitude: 48.81470406056698, longitude: 2.2972847301706394, lines: ['13'] }),
#   (STATION_8c9a711d7688a76851f548ab27acc6e67e34a0be:Station { name: "Malesherbes", latitude: 48.88253647289218, longitude: 2.3110092430055142, lines: ['3'] }),
#   (STATION_03c7175a51815565ba1eb40eda957248f2298c65:Station { name: "Maraîchers", latitude: 48.8526004024001, longitude: 2.4063849895661398, lines: ['9'] }),
#   (STATION_2f959f140588c366a10c4935cbfaa8320a29598d:Station { name: "Marcel Sembat", latitude: 48.83380858698028, longitude: 2.243480614417395, lines: ['9'] }),
#   (STATION_505193811ad63cbc679712fa65ad57657f7bb0fc:Station { name: "Marx-Dormoy", latitude: 48.89037408122113, longitude: 2.359797008670612, lines: ['12'] }),
#   (STATION_78cedf166ab2501a5ee239ba7f30f23c46e0ddb1:Station { name: "La Défense (Grande Arche)", latitude: 48.89182675483652, longitude: 2.237992043215619, lines: ['1'] }),
#   (STATION_c4d3ac6fb8b2cf918867c9bf0b6e336ba5951ebf:Station { name: "Guy-Môquet", latitude: 48.893009056051206, longitude: 2.327495839490489, lines: ['13'] }),
#   (STATION_f3170bc77e16934e4137a2ca79d746e1a0251246:Station { name: "Havre-Caumartin", latitude: 48.87346189067039, longitude: 2.3284804844734768, lines: ['3', '9'] }),
#   (STATION_30b762bdaa2f5b353b50c3b739bb0f978973be48:Station { name: "Hoche", latitude: 48.891499383764256, longitude: 2.4031249606560765, lines: ['5'] }),
#   (STATION_1af77b3af744ef1c2bc2dda079e8d59b949f0b95:Station { name: "Hôtel de Ville", latitude: 48.85735592716952, longitude: 2.3520735668587185, lines: ['1', '11'] }),
#   (STATION_e03a369704702f6d0a1b78f2db421118658171e8:Station { name: "Iéna", latitude: 48.864350199647255, longitude: 2.2940452637830906, lines: ['9'] }),
#   (STATION_36acbd80447d097f03400587c2b6b70c13852bf2:Station { name: "Invalides", latitude: 48.86085078966753, longitude: 2.3145481126266487, lines: ['13', '8'] }),
#   (STATION_8af7473ef1ff95ee010a441cce8974c55cd70f7c:Station { name: "Jacques-Bonsergent", latitude: 48.870700823269566, longitude: 2.3605786355872773, lines: ['5'] }),
#   (STATION_2f6f33ddbd0f92b059d8d2ee0d63139edf2418e8:Station { name: "Jasmin", latitude: 48.85243851922266, longitude: 2.2679339230009505, lines: ['9'] }),
#   (STATION_b1aa6730918fef3a4cb269211422c7d6f707e76e:Station { name: "Jaurès", latitude: 48.88276854674882, longitude: 2.36994579899074, lines: ['2', '5', '7B'] }),
#   (STATION_47d688d32a4055db4cd7d5532e84f048f038571d:Station { name: "Javel-André-Citroen", latitude: 48.84596388048408, longitude: 2.277815126353772, lines: ['10'] }),
#   (STATION_0502dfd9eb1689d43709978d14d3842f37d2e48e:Station { name: "Jourdain", latitude: 48.875248294624974, longitude: 2.389329434152641, lines: ['11'] }),
#   (STATION_65e776e819531dee48ed6f4713e1ea486071a81a:Station { name: "Jules Joffrin", latitude: 48.89249697693025, longitude: 2.3443284105515048, lines: ['12'] }),
#   (STATION_472fe5b84e856bbef75af57174a2c080d15c3de0:Station { name: "Jussieu", latitude: 48.8459684322046, longitude: 2.3548073926942186, lines: ['7', '10'] }),
#   (STATION_2d2df4ec9a0f70791ac352053134564a10267f3c:Station { name: "Kléber", latitude: 48.87130614908782, longitude: 2.293331020896217, lines: ['6'] }),
#   (STATION_e5f54470c0d87d895f3264b122aa66128abadbeb:Station { name: "La Chapelle", latitude: 48.88438869835817, longitude: 2.3592765642767297, lines: ['2'] }),
#   (STATION_6313e78f5baa9470fe6365c3377c0c5efd0d3476:Station { name: "La Courneuve-8-Mai-1945", latitude: 48.920514506685684, longitude: 2.410225779120198, lines: ['7'] }),
#   (STATION_f94b92bb35ab31e8a10fc914cb5ae6ab4fb96399:Station { name: "La Muette", latitude: 48.85809504968323, longitude: 2.274096448110612, lines: ['9'] }),
#   (STATION_c835ca8bda6f343c3ffc82c03abf988d8fb15f98:Station { name: "Lamarck-Caulaincourt", latitude: 48.8897381077178, longitude: 2.339149086674118, lines: ['12'] }),
#   (STATION_626d2369c2ed4ebe0acd243dc045987cb2c78a6b:Station { name: "Laumière", latitude: 48.884931610546104, longitude: 2.3790912468998378, lines: ['5'] }),
#   (STATION_8eab7384026467e4ff73dfafe259f333b26dacf4:Station { name: "Le Kremlin-Bicêtre", latitude: 48.81038512512949, longitude: 2.3618306830911315, lines: ['7'] }),
#   (STATION_9ef81cbd355cd26070ae32952fb56dc7bac84d2c:Station { name: "Dupleix", latitude: 48.850392578319685, longitude: 2.2936483362305387, lines: ['6'] }),
#   (STATION_4f59b7938f20f79a8706ad517bff0d29e5fb88e9:Station { name: "Duroc", latitude: 48.84684876889597, longitude: 2.3169373108340854, lines: ['10', '13'] }),
#   (STATION_bdeb4600290f1fea8ff4eb0991aa1d3323ea800d:Station { name: "Edgar-Quinet", latitude: 48.84056772620437, longitude: 2.326402815222764, lines: ['6'] }),
#   (STATION_e0a265979c892601ce78fb7a1963cee8cd997419:Station { name: "Eglise de Pantin", latitude: 48.893632527974006, longitude: 2.41290026603005, lines: ['5'] }),
#   (STATION_a76c2e72e7839882a1267eaf4faf90556cde3ea4:Station { name: "Esplanade de la Défense", latitude: 48.888358060166176, longitude: 2.2499372128628017, lines: ['1'] }),
#   (STATION_ef3622a8ec96ef956f6edc9c3e37ffb14a2c03b0:Station { name: "Etienne Marcel", latitude: 48.86371036646956, longitude: 2.3489831961271017, lines: ['4'] }),
#   (STATION_576347ec826f38428d8c8a6f8ec4acb2bceab911:Station { name: "Europe", latitude: 48.87906043921274, longitude: 2.3229746324058937, lines: ['3'] }),
#   (STATION_2ef91238378eabfd468652ec308268ef6e658575:Station { name: "Exelmans", latitude: 48.84290697853592, longitude: 2.260144397880896, lines: ['9'] }),
#   (STATION_a00878cb930d298fbf950d3c79de60c039f216e2:Station { name: "Falguière", latitude: 48.844323383002006, longitude: 2.317564676180599, lines: ['12'] }),
#   (STATION_4b2f7ab54cb1fd70196d0e24c66ad3542429c8b6:Station { name: "Fort d'Aubervilliers", latitude: 48.91405674514657, longitude: 2.4035763345110066, lines: ['7'] }),
#   (STATION_2940067301a5987a9e89702d7f587ad4e8a53233:Station { name: "Franklin-Roosevelt", latitude: 48.86901042793761, longitude: 2.3102531808960265, lines: ['1', '9'] }),
#   (STATION_1baddc8f6d9d01326459e40635d087cff47a9f80:Station { name: "Gabriel-Péri", latitude: 48.91657483598322, longitude: 2.2943289646870606, lines: ['13'] }),
#   (STATION_2bbeb111a0aa50b781e956d926e7eb5c17041657:Station { name: "Gaîté", latitude: 48.83875182138865, longitude: 2.322509186224712, lines: ['13'] }),
#   (STATION_d8ab301185ccad5afdbf5d86b5ad01cf6cf42615:Station { name: "Gallieni (Parc de Bagnolet)", latitude: 48.864834901238424, longitude: 2.416604379961874, lines: ['3'] }),
#   (STATION_92b9bb5007dec1d038f09121dfaffc7e3f05da2b:Station { name: "Gare d'Austerlitz", latitude: 48.843414224143714, longitude: 2.3641883928676424, lines: ['5', '10'] }),
#   (STATION_6cf14fef55be47246e631c340c7cb98d8b58cb69:Station { name: "Gare de l'Est (Verdun)", latitude: 48.87669583602489, longitude: 2.3579925105504023, lines: ['4', '7', '5'] }),
#   (STATION_606a57970dd56d2000e113caee98a04ce179ab33:Station { name: "Gare du Nord", latitude: 48.87974306422535, longitude: 2.3546008104722334, lines: ['4', '5'] }),
#   (STATION_6597c38c88e72f3dd673456929277f7a2ecb9e40:Station { name: "Garibaldi", latitude: 48.906382164226436, longitude: 2.331910473458932, lines: ['13'] }),
#   (STATION_474a38ef7256e4c04ffd179dfafc4574d9d254ed:Station { name: "George V", latitude: 48.87204561942635, longitude: 2.300769185644953, lines: ['1'] }),
#   (STATION_be6e9def90707d65e548dea30aaaee51156595f6:Station { name: "Glacière", latitude: 48.8312479519874, longitude: 2.343122075822986, lines: ['6'] }),
#   (STATION_02c0bf213d2224b0a4dcaeb876f74a4826e43328:Station { name: "Goncourt (Hôpital Saint-Louis)", latitude: 48.87001535524704, longitude: 2.370768799021465, lines: ['11'] }),
#   (STATION_b558696031c3cffc84a8b75f083d9ea85f2abb44:Station { name: "Châtillon Montrouge", latitude: 48.81028336351076, longitude: 2.301288870975952, lines: ['13'] }),
#   (STATION_cadaa3e09a399e6c7fd22470e6c6bcd1c553bcb8:Station { name: "Chaussée d'Antin (La Fayette)", latitude: 48.87298582466517, longitude: 2.33342622405285, lines: ['7', '9'] }),
#   (STATION_df37832123be5dbfc2515403b197902dd913bbc3:Station { name: "Chevaleret", latitude: 48.83496497071996, longitude: 2.3680913458793973, lines: ['6'] }),
#   (STATION_2b0066349f7dc1eea12d8144e01eea2760fa15bd:Station { name: "Cité", latitude: 48.855684850286295, longitude: 2.346202929528716, lines: ['4'] }),
#   (STATION_320c62523ca8bb8d21b3f07bafb5945f820a4bbe:Station { name: "Cluny-La Sorbonne", latitude: 48.85079575570429, longitude: 2.3450308883652258, lines: ['10'] }),
#   (STATION_3400ce5e054518588c459457dc94d33900647216:Station { name: "Colonel Fabien", latitude: 48.87818498179218, longitude: 2.3701745466363584, lines: ['2'] }),
#   (STATION_f746272ee24566a0fd487003f12ab8fa9ed79457:Station { name: "Concorde", latitude: 48.86567809641779, longitude: 2.3211937718018665, lines: ['1', '12', '8'] }),
#   (STATION_fa84f17a51b78d2a399b863b5b81838719cacf24:Station { name: "Convention", latitude: 48.83713694956265, longitude: 2.296396090155559, lines: ['12'] }),
#   (STATION_4ea9bc6cf0dd63e6d4cbd45a726ed01a63461461:Station { name: "Corentin-Cariou", latitude: 48.89468154198811, longitude: 2.3823021939742417, lines: ['7'] }),
#   (STATION_d043c705abf04852fd0046a276a3cbe7842a5ea2:Station { name: "Corentin-Celton", latitude: 48.82682988739414, longitude: 2.278966861574341, lines: ['12'] }),
#   (STATION_e96d0bc8ad75e9a23dca581614f11c7bfef219cb:Station { name: "Corvisart", latitude: 48.8298632521128, longitude: 2.3506227279320897, lines: ['6'] }),
#   (STATION_f24acdd72b8e37dc605ae6bd89b155513e9cb218:Station { name: "Courcelles", latitude: 48.879272151631575, longitude: 2.303298546682486, lines: ['2'] }),
#   (STATION_26d357d9d14306f0d454f232c784a66b9673e7ae:Station { name: "Croix-de-Chavaux (Jacques Duclos)", latitude: 48.857999073258, longitude: 2.435866895674707, lines: ['9'] }),
#   (STATION_448bd843dd8fd8ae53390787a38290c7895372c2:Station { name: "Denfert-Rochereau", latitude: 48.83427681284463, longitude: 2.332203797304786, lines: ['4', '6'] }),
#   (STATION_5348bbc312c4bda9be1d83aea5aa7e9e9a163d23:Station { name: "Bonne Nouvelle", latitude: 48.87049583233104, longitude: 2.348862117440598, lines: ['9', '8'] }),
#   (STATION_5643399a0a0e21e1b7b740bf56b4b33d69c9cf1d:Station { name: "Botzaris", latitude: 48.879607088933135, longitude: 2.389415569653207, lines: ['7B'] }),
#   (STATION_e85d370ddb52a38cf52763e077b6c307ca49f061:Station { name: "Boulogne-Jean-Jaurès", latitude: 48.84228014352973, longitude: 2.238862975367271, lines: ['10'] }),
#   (STATION_d47bbe270cb9f9d3cb273ed61e2e7d596755e6c4:Station { name: "Boulogne Pont de Saint-Cloud", latitude: 48.84068016312196, longitude: 2.228313661724341, lines: ['10'] }),
#   (STATION_97c353bcc81bc4670736e7c785c82327cda40e28:Station { name: "Bourse", latitude: 48.86876179259638, longitude: 2.3406741288121005, lines: ['3'] }),
#   (STATION_5f107f45f0ab00cb8c09fe85f699283318da267f:Station { name: "Bréguet-Sabin", latitude: 48.85680394896092, longitude: 2.3705968196318707, lines: ['5'] }),
#   (STATION_fb913b172e45773cb6d0e441255bd4a121d3caa1:Station { name: "Brochant", latitude: 48.89062663302413, longitude: 2.320191121275328, lines: ['13'] }),
#   (STATION_386616ec923be88788216bde9dc38f6ea76a5049:Station { name: "Buttes-Chaumont", latitude: 48.87780395600785, longitude: 2.3812110997359883, lines: ['7B'] }),
#   (STATION_47642cdcf761e0f0cb02a7b89be67f7db9416dcc:Station { name: "Buzenval", latitude: 48.8517674745052, longitude: 2.4011814838726444, lines: ['9'] }),
#   (STATION_4f498969051a2dad4b28bad8dda6a0a68c39e93a:Station { name: "Cadet", latitude: 48.87582571803818, longitude: 2.3433451245732733, lines: ['7'] }),
#   (STATION_972d8fa5f24638738b7959bbbb2b59e7e5a1113d:Station { name: "Cambronne", latitude: 48.847699108170794, longitude: 2.3020391436692633, lines: ['6'] }),
#   (STATION_ba2087c1c00f556ee1de6151e4ad85f6d1ba91a0:Station { name: "Campo-Formio", latitude: 48.835551216675434, longitude: 2.358752095191401, lines: ['5'] }),
#   (STATION_c3e0633bc8abcbd5f4b5fa674ea4a4f015ceaad6:Station { name: "Cardinal-Lemoine", latitude: 48.84670586906026, longitude: 2.351335178972595, lines: ['10'] }),
#   (STATION_309c1cbbc59ae04138a533d99291f591cc1ffd0a:Station { name: "Censier-Daubenton", latitude: 48.84059430000161, longitude: 2.351755612946688, lines: ['7'] }),
#   (STATION_01c78d2eb967dfe6a12a6d015d74f7c0c1916971:Station { name: "Champs-Elysées-Clémenceau", latitude: 48.86736657046978, longitude: 2.3141910633936584, lines: ['13', '1'] }),
#   (STATION_fe8fd40a7535f0ef44980b9b8da2e03a74ea21d7:Station { name: "Chardon-Lagache", latitude: 48.845104139567006, longitude: 2.266936059032254, lines: ['10'] }),
#   (STATION_601f3120c24af223b38620c24e13ab9dd43b3f63:Station { name: "Charles de Gaulle-Etoile", latitude: 48.8739310942679, longitude: 2.295127251650101, lines: ['1', '2', '6'] }),
#   (STATION_5a903df61d9de7161699e9dad5059e1f6cad8f28:Station { name: "Charles Michels", latitude: 48.846362975500796, longitude: 2.2856310658828742, lines: ['10'] }),
#   (STATION_7e2502dafd12e72df5345ccf3974440dceb29b6a:Station { name: "Charonne", latitude: 48.854642047444784, longitude: 2.385032193334828, lines: ['9'] }),
#   (STATION_9773cfdb7a74e6b655fe195a3b483cce30b6ee2c:Station { name: "Château Rouge", latitude: 48.88708628305045, longitude: 2.3493700732513783, lines: ['4'] }),
#   (STATION_7d09bd83710be1d73b31d5d6ac57e784bb4a30b0:Station { name: "Château d'Eau", latitude: 48.87245415091989, longitude: 2.3560561681302907, lines: ['4'] }),
#   (STATION_9e23e8f481e69e44a5d39b27f4f664061aa934f7:Station { name: "Château de Vincennes", latitude: 48.844325144368575, longitude: 2.4405523462118217, lines: ['1'] }),
#   (STATION_32b6366f95f25aaa6f47d3a71da621be8f899a9e:Station { name: "Abbesses", latitude: 48.8843997149084, longitude: 2.338399384171042, lines: ['12'] }),
#   (STATION_72b1804beac25fad477e085c2ffa0674164d017c:Station { name: "Alésia", latitude: 48.82806601968645, longitude: 2.326827420050836, lines: ['4'] }),
#   (STATION_9f33a444b886d90de1d950e76ede886e079ac8d7:Station { name: "Alexandre-Dumas", latitude: 48.856408399657575, longitude: 2.394499757609273, lines: ['2'] }),
#   (STATION_d911e926acb4794e8e8dc281d728b1ef2dfe0095:Station { name: "Alma-Marceau", latitude: 48.86429867104668, longitude: 2.3012514104499293, lines: ['9'] }),
#   (STATION_5d1fd66ab6dbc7effd681dcb0b80bc7a003ff5c1:Station { name: "Anatole-France", latitude: 48.89201862632888, longitude: 2.2855174447944844, lines: ['3'] }),
#   (STATION_dabc5de2f5470d7f041a6bcdfd0111534ea82d41:Station { name: "Anvers", latitude: 48.88287169018058, longitude: 2.344163572800391, lines: ['2'] }),
#   (STATION_b078fabb7e3098f1e22f859e40e6b9f1cb7ad5fd:Station { name: "Argentine", latitude: 48.87567248598795, longitude: 2.289444164481448, lines: ['1'] }),
#   (STATION_69dc006fa263f07ffb170c79a5a8a6b17446e1ae:Station { name: "Arts-et-Métiers", latitude: 48.865551863634785, longitude: 2.356108155120312, lines: ['3', '11'] }),
#   (STATION_641292a514a250021318903759a4a0ee63cef015:Station { name: "Assemblée Nationale", latitude: 48.86145390429486, longitude: 2.320309690507356, lines: ['12'] }),
#   (STATION_a7b201bab2bbc9d712207978366d86f9e8f0a68a:Station { name: "Aubervilliers Pantin (4 Chemins)", latitude: 48.90389804752947, longitude: 2.3924800786724747, lines: ['7'] }),
#   (STATION_4c1e472382841b4bf41fc1fb407ba6d05ceaa5a8:Station { name: "Avenue Emile-Zola", latitude: 48.846852151949776, longitude: 2.2954488279344742, lines: ['10'] }),
#   (STATION_504138c46372b7fc6cabbbf708356ed71d9b8604:Station { name: "Avron", latitude: 48.851193819213286, longitude: 2.398239140823123, lines: ['2'] }),
#   (STATION_dcdc07d112745a5c31d4d6e75e6a2f4643d84beb:Station { name: "Barbès-Rochechouart", latitude: 48.88393176993443, longitude: 2.3493557085996466, lines: ['4', '2'] }),
#   (STATION_90502b0150a1c49ae19163fad0c654370b026b83:Station { name: "Bastille", latitude: 48.852975674654225, longitude: 2.3692188244433434, lines: ['1', '5', '8'] }),
#   (STATION_d1e34d591bc7cc29cdf28a732a372de27a995daf:Station { name: "Bel-Air", latitude: 48.841432006648255, longitude: 2.4008691933800934, lines: ['6'] }),
#   (STATION_a67dd146dd1d9a723b866e35a94e57653d4dc553:Station { name: "Belleville", latitude: 48.87194579797485, longitude: 2.3767510413737996, lines: ['11', '2'] }),
#   (STATION_5b02b0e7ad4f13515b5b21e41413a312bb3a1656:Station { name: "Bérault", latitude: 48.84536875015732, longitude: 2.428244509620486, lines: ['1'] }),
#   (STATION_848d0cc8f234d3abe11ab481d9cf7bcdacba3da5:Station { name: "Bir-Hakeim (Grenelle)", latitude: 48.85432721855236, longitude: 2.2888101037361173, lines: ['6'] }),
#   (STATION_d822dbfc82ba77efa66a5c6d2bc41132f8359840:Station { name: "Blanche", latitude: 48.88377051883179, longitude: 2.332485148274094, lines: ['2'] }),
#   (STATION_837c0165375f26b02f2ab7bfcbc12b319959cbd9:Station { name: "Bobigny-Pantin (Raymond Queneau)", latitude: 48.895799232549, longitude: 2.4248572983975945, lines: ['5'] }),
#   (STATION_bb486c21f875b9921a20720867263ba5a6ddf8c8:Station { name: "Boissière", latitude: 48.86685615476034, longitude: 2.2900380734450088, lines: ['6'] }),
#   (STATION_e333dd72f55a3090f60757ae2dbf4f1380ddbcd2:Station { name: "Bolivar", latitude: 48.880790122828465, longitude: 2.3741551266626466, lines: ['7B'] }),
#   (STATION_7eb016d3a2323c7d1ce227854286219b642a86ee:Station { name: "Couronnes", latitude: 48.869329169496574, longitude: 2.3805363661617247, lines: ['2'] }),
#   (STATION_f36323c9dbc938c71982d443d89a29ae8ce93139:Station { name: "Crimée", latitude: 48.89028877504466, longitude: 2.3767786489253644, lines: ['7'] }),
#   (STATION_adad54152cb7ff75f90c54c343d62b33bb7cd925:Station { name: "Daumesnil (Félix Eboué)", latitude: 48.83937646312499, longitude: 2.3957880604156494, lines: ['6', '8'] }),
#   (STATION_c3f5ce5ad6f874b66e74902633b2a6e9daa93e8a:Station { name: "Dugommier", latitude: 48.83887615167853, longitude: 2.389347387570293, lines: ['6'] }),
#   (STATION_dd6813dbcef26961f31c0c8343f84edd09d4603c:Station { name: "Château Landon", latitude: 48.87845656683119, longitude: 2.3620537162488997, lines: ['7'] }),
#   (STATION_abaafe8811ad9380c0d1f63ac78abba7aadfaad0:Station { name: "Billancourt", latitude: 48.83208764428255, longitude: 2.2381607768755143, lines: ['9'] }),
#   (STATION_db281d1fc3d3fae6c4ebdf3f24a3cdce85bf7654:Station { name: "Bobigny-Pablo-Picasso", latitude: 48.90714731255157, longitude: 2.44945750453114, lines: ['5'] }),
#   (STATION_95522c347b146d757cea656446cbab38267639e8:Station { name: "Eglise d'Auteuil", latitude: 48.847532242116614, longitude: 2.2694792821877074, lines: ['10'] }),
#   (STATION_c6d47074acd46aeeecadff1d372279a9482154c7:Station { name: "Porte d'Auteuil", latitude: 48.848225980411186, longitude: 2.257698885660922, lines: ['10'] }),
#   (STATION_49a11b3e18833b4d42e04a25bc184481eb9ca4fd:Station { name: "Balard", latitude: 48.83681498880598, longitude: 2.2786833464502703, lines: ['8'] }),
#   (STATION_ec91edf25366a6da7817cd540c35420a3ff816e8:Station { name: "Lourmel", latitude: 48.838668129030076, longitude: 2.2822484883840986, lines: ['8'] }),
#   (STATION_fd4b66e847f174c66a46e36af10f63a689e8f31d:Station { name: "Boucicaut", latitude: 48.841025355321676, longitude: 2.287923867330867, lines: ['8'] }),
#   (STATION_13bd76f7307ccca0280613f5a04c0abf09452df5:Station { name: "Félix Faure", latitude: 48.84282456767407, longitude: 2.292224966220516, lines: ['8'] }),
#   (STATION_d3440a619712787b175061cd50363b9848abaca7:Station { name: "Commerce", latitude: 48.84461367199405, longitude: 2.293802980169146, lines: ['8'] }),
#   (STATION_38824badd3cdab23afdf75ad56cf168eda709b55:Station { name: "Ecole Militaire", latitude: 48.85426092155411, longitude: 2.3054395605390106, lines: ['8'] }),
#   (STATION_10f64f0e31cf27ec5b6807cee1252f39b74f342d:Station { name: "La Tour-Maubourg", latitude: 48.857227860649644, longitude: 2.3097962258273563, lines: ['8'] }),
#   (STATION_c696c6b2f12c66ce0bbf3200d9e7edb75d29a776:Station { name: "Filles du Calvaire", latitude: 48.86307817635541, longitude: 2.36674588358473, lines: ['8'] }),
#   (STATION_426a319f1382046c43424b2528fe233ff80ebc6a:Station { name: "Saint-Sébastien-Froissart", latitude: 48.860974997187185, longitude: 2.3672622950229414, lines: ['8'] }),
#   (STATION_a8269959cc33ef92241e57d4c759f3c0dcbe9335:Station { name: "Chemin Vert", latitude: 48.85758654446453, longitude: 2.368036694948376, lines: ['8'] }),
#   (STATION_cce50a1b264c58b04ce82bb8c5fb4d6cadb41176:Station { name: "Ledru-Rollin", latitude: 48.85119416536367, longitude: 2.3759317370128947, lines: ['8'] }),
#   (STATION_f749ea339c2e053c3694c9400d8dec557c70b7bc:Station { name: "Faidherbe-Chaligny", latitude: 48.85006766800271, longitude: 2.384428770741632, lines: ['8'] }),
#   (STATION_934eb1bbd24b37d855e7b3e1156e883b739a332e:Station { name: "Montgallet", latitude: 48.84440309209688, longitude: 2.39025165315774, lines: ['8'] }),
#   (STATION_6fb4a53b805cfb9ceed8b722cb0e95bc2f805596:Station { name: "Michel Bizot", latitude: 48.83699103765297, longitude: 2.402919606870042, lines: ['8'] }),
#   (STATION_97e0d5797ca034486af2575f5eac760afe216d52:Station { name: "Porte Dorée", latitude: 48.83549725282465, longitude: 2.4061852122149348, lines: ['8'] }),
# ...
#   (STOP_2172)-[:TRANSFER { transfer_time: 96 }]->(STOP_2170),
#   (STOP_2185)-[:TRANSFER { transfer_time: 101 }]->(STOP_1997),
#   (STOP_2185)-[:TRANSFER { transfer_time: 80 }]->(STOP_2186),
#   (STOP_2201)-[:TRANSFER { transfer_time: 300 }]->(STOP_1945),
#   (STOP_2201)-[:TRANSFER { transfer_time: 300 }]->(STOP_2200),
#   (STOP_2205)-[:TRANSFER { transfer_time: 107 }]->(STOP_1659),
#   (STOP_2205)-[:TRANSFER { transfer_time: 111 }]->(STOP_2539),
#   (STOP_2207)-[:TRANSFER { transfer_time: 129 }]->(STOP_1951),
#   (STOP_2207)-[:TRANSFER { transfer_time: 145 }]->(STOP_2206),
#   (STOP_2208)-[:TRANSFER { transfer_time: 59 }]->(STOP_1954),
#   (STOP_2208)-[:TRANSFER { transfer_time: 100 }]->(STOP_2209),
#   (STOP_2212)-[:TRANSFER { transfer_time: 420 }]->(STOP_1910),
#   (STOP_2212)-[:TRANSFER { transfer_time: 420 }]->(STOP_2235),
#   (STOP_2213)-[:TRANSFER { transfer_time: 420 }]->(STOP_1910),
#   (STOP_2213)-[:TRANSFER { transfer_time: 184 }]->(STOP_1957),
#   (STOP_2213)-[:TRANSFER { transfer_time: 145 }]->(STOP_2212),
#   (STOP_2213)-[:TRANSFER { transfer_time: 420 }]->(STOP_2235),
#   (STOP_2219)-[:TRANSFER { transfer_time: 180 }]->(STOP_1166834),
#   (STOP_2219)-[:TRANSFER { transfer_time: 180 }]->(STOP_1166835),
#   (STOP_2219)-[:TRANSFER { transfer_time: 400 }]->(STOP_1965),
#   (STOP_2219)-[:TRANSFER { transfer_time: 271 }]->(STOP_1966),
#   (STOP_2219)-[:TRANSFER { transfer_time: 104 }]->(STOP_2036),
#   (STOP_2219)-[:TRANSFER { transfer_time: 130 }]->(STOP_2155),
#   (STOP_2219)-[:TRANSFER { transfer_time: 400 }]->(STOP_2220),
#   (STOP_2219)-[:TRANSFER { transfer_time: 262 }]->(STOP_2221),
#   (STOP_2220)-[:TRANSFER { transfer_time: 240 }]->(STOP_2036),
#   (STOP_2220)-[:TRANSFER { transfer_time: 210 }]->(STOP_2155),
#   (STOP_2221)-[:TRANSFER { transfer_time: 360 }]->(STOP_1166834),
#   (STOP_2221)-[:TRANSFER { transfer_time: 360 }]->(STOP_1166835),
#   (STOP_2221)-[:TRANSFER { transfer_time: 250 }]->(STOP_1965),
#   (STOP_2221)-[:TRANSFER { transfer_time: 255 }]->(STOP_2036),
#   (STOP_2221)-[:TRANSFER { transfer_time: 284 }]->(STOP_2155),
#   (STOP_2221)-[:TRANSFER { transfer_time: 123 }]->(STOP_2220),
#   (STOP_2226)-[:TRANSFER { transfer_time: 119 }]->(STOP_1972),
#   (STOP_2226)-[:TRANSFER { transfer_time: 86 }]->(STOP_2227),
#   (STOP_2233)-[:TRANSFER { transfer_time: 76 }]->(STOP_1907),
#   (STOP_2233)-[:TRANSFER { transfer_time: 78 }]->(STOP_2232),
#   (STOP_2241)-[:TRANSFER { transfer_time: 133 }]->(STOP_1657),
#   (STOP_2241)-[:TRANSFER { transfer_time: 133 }]->(STOP_2537),
#   (STOP_2252)-[:TRANSFER { transfer_time: 152 }]->(STOP_1928),
#   (STOP_2252)-[:TRANSFER { transfer_time: 144 }]->(STOP_2253),
#   (STOP_2285)-[:TRANSFER { transfer_time: 77 }]->(STOP_1890),
#   (STOP_2285)-[:TRANSFER { transfer_time: 86 }]->(STOP_2286),
#   (STOP_2289)-[:TRANSFER { transfer_time: 144 }]->(STOP_1892),
#   (STOP_2289)-[:TRANSFER { transfer_time: 168 }]->(STOP_2288),
#   (STOP_2297)-[:TRANSFER { transfer_time: 229 }]->(STOP_1900),
#   (STOP_2297)-[:TRANSFER { transfer_time: 168 }]->(STOP_1902),
#   (STOP_2297)-[:TRANSFER { transfer_time: 225 }]->(STOP_2296),
#   (STOP_2297)-[:TRANSFER { transfer_time: 161 }]->(STOP_2298),
#   (STOP_2298)-[:TRANSFER { transfer_time: 133 }]->(STOP_1900),
#   (STOP_2298)-[:TRANSFER { transfer_time: 133 }]->(STOP_2296),
#   (STOP_2310)-[:TRANSFER { transfer_time: 106 }]->(STOP_1844),
#   (STOP_2310)-[:TRANSFER { transfer_time: 110 }]->(STOP_2311),
#   (STOP_2313)-[:TRANSFER { transfer_time: 88 }]->(STOP_1847),
#   (STOP_2313)-[:TRANSFER { transfer_time: 119 }]->(STOP_2314),
#   (STOP_2327)-[:TRANSFER { transfer_time: 70 }]->(STOP_1861),
#   (STOP_2327)-[:TRANSFER { transfer_time: 60 }]->(STOP_2328),
#   (STOP_2336)-[:TRANSFER { transfer_time: 180 }]->(STOP_1166838),
#   (STOP_2336)-[:TRANSFER { transfer_time: 180 }]->(STOP_1166839),
#   (STOP_2338)-[:TRANSFER { transfer_time: 138 }]->(STOP_1651),
#   (STOP_2338)-[:TRANSFER { transfer_time: 74 }]->(STOP_1832),
#   (STOP_2338)-[:TRANSFER { transfer_time: 89 }]->(STOP_2371),
#   (STOP_2338)-[:TRANSFER { transfer_time: 122 }]->(STOP_2531),
#   (STOP_2339)-[:TRANSFER { transfer_time: 200 }]->(STOP_1651),
#   (STOP_2339)-[:TRANSFER { transfer_time: 90 }]->(STOP_1832),
#   (STOP_2339)-[:TRANSFER { transfer_time: 90 }]->(STOP_1833),
#   (STOP_2339)-[:TRANSFER { transfer_time: 90 }]->(STOP_2338),
#   (STOP_2339)-[:TRANSFER { transfer_time: 90 }]->(STOP_2371),
#   (STOP_2339)-[:TRANSFER { transfer_time: 200 }]->(STOP_2531),
#   (STOP_2354)-[:TRANSFER { transfer_time: 89 }]->(STOP_1814),
#   (STOP_2354)-[:TRANSFER { transfer_time: 71 }]->(STOP_2353),
#   (STOP_2359)-[:TRANSFER { transfer_time: 51 }]->(STOP_1819),
#   (STOP_2359)-[:TRANSFER { transfer_time: 56 }]->(STOP_2358),
#   (STOP_2363)-[:TRANSFER { transfer_time: 367 }]->(STOP_1825),
#   (STOP_2363)-[:TRANSFER { transfer_time: 108 }]->(STOP_1826),
#   (STOP_2363)-[:TRANSFER { transfer_time: 311 }]->(STOP_1827),
#   (STOP_2363)-[:TRANSFER { transfer_time: 381 }]->(STOP_2364),
#   (STOP_2363)-[:TRANSFER { transfer_time: 108 }]->(STOP_2365),
#   (STOP_2363)-[:TRANSFER { transfer_time: 289 }]->(STOP_2366),
#   (STOP_2364)-[:TRANSFER { transfer_time: 126 }]->(STOP_1827),
#   (STOP_2364)-[:TRANSFER { transfer_time: 113 }]->(STOP_2366),
#   (STOP_2365)-[:TRANSFER { transfer_time: 293 }]->(STOP_1825),
#   (STOP_2365)-[:TRANSFER { transfer_time: 235 }]->(STOP_1827),
#   (STOP_2365)-[:TRANSFER { transfer_time: 307 }]->(STOP_2364),
#   (STOP_2365)-[:TRANSFER { transfer_time: 264 }]->(STOP_2366),
#   (STOP_2375)-[:TRANSFER { transfer_time: 137 }]->(STOP_1764),
#   (STOP_2375)-[:TRANSFER { transfer_time: 79 }]->(STOP_2374),
#   (STOP_2376)-[:TRANSFER { transfer_time: 130 }]->(STOP_1647),
#   (STOP_2376)-[:TRANSFER { transfer_time: 79 }]->(STOP_1767),
#   (STOP_2376)-[:TRANSFER { transfer_time: 153 }]->(STOP_2377),
#   (STOP_2376)-[:TRANSFER { transfer_time: 118 }]->(STOP_2527),
#   (STOP_2376)-[:TRANSFER { transfer_time: 180 }]->(STOP_967988),
#   (STOP_2376)-[:TRANSFER { transfer_time: 180 }]->(STOP_967989),
#   (STOP_2377)-[:TRANSFER { transfer_time: 130 }]->(STOP_1647),
#   (STOP_2377)-[:TRANSFER { transfer_time: 117 }]->(STOP_2527),
#   (STOP_2377)-[:TRANSFER { transfer_time: 180 }]->(STOP_967988),
#   (STOP_2377)-[:TRANSFER { transfer_time: 180 }]->(STOP_967989),
#   (STOP_2384)-[:TRANSFER { transfer_time: 89 }]->(STOP_1773),
#   (STOP_2384)-[:TRANSFER { transfer_time: 99 }]->(STOP_2383),
#   (STOP_2392)-[:TRANSFER { transfer_time: 121 }]->(STOP_1781),
#   (STOP_2392)-[:TRANSFER { transfer_time: 111 }]->(STOP_2391),
#   (STOP_2395)-[:TRANSFER { transfer_time: 93 }]->(STOP_1784),
#   (STOP_2395)-[:TRANSFER { transfer_time: 87 }]->(STOP_2394),
#   (STOP_2402)-[:TRANSFER { transfer_time: 129 }]->(STOP_1791),
#   (STOP_2402)-[:TRANSFER { transfer_time: 122 }]->(STOP_2401),
#   (STOP_2403)-[:TRANSFER { transfer_time: 129 }]->(STOP_1648),
#   (STOP_2403)-[:TRANSFER { transfer_time: 90 }]->(STOP_1794),
#   (STOP_2403)-[:TRANSFER { transfer_time: 90 }]->(STOP_2404),
#   (STOP_2403)-[:TRANSFER { transfer_time: 118 }]->(STOP_2528),
#   (STOP_2405)-[:TRANSFER { transfer_time: 119 }]->(STOP_1796),
#   (STOP_2405)-[:TRANSFER { transfer_time: 125 }]->(STOP_2406),
#   (STOP_2430)-[:TRANSFER { transfer_time: 139 }]->(STOP_1753),
#   (STOP_2430)-[:TRANSFER { transfer_time: 140 }]->(STOP_2431),
#   (STOP_2435)-[:TRANSFER { transfer_time: 180 }]->(STOP_6129304),
#   (STOP_2435)-[:TRANSFER { transfer_time: 180 }]->(STOP_6129305),
#   (STOP_2467)-[:TRANSFER { transfer_time: 180 }]->(STOP_1166840),
#   (STOP_2467)-[:TRANSFER { transfer_time: 180 }]->(STOP_1166841),
#   (STOP_2467)-[:TRANSFER { transfer_time: 480 }]->(STOP_1715),
#   (STOP_2467)-[:TRANSFER { transfer_time: 263 }]->(STOP_1723),
#   (STOP_2467)-[:TRANSFER { transfer_time: 118 }]->(STOP_1724),
#   (STOP_2467)-[:TRANSFER { transfer_time: 480 }]->(STOP_2460),
#   (STOP_2467)-[:TRANSFER { transfer_time: 253 }]->(STOP_2468),
#   (STOP_2467)-[:TRANSFER { transfer_time: 108 }]->(STOP_2469),
#   (STOP_2468)-[:TRANSFER { transfer_time: 180 }]->(STOP_1166840),
#   (STOP_2468)-[:TRANSFER { transfer_time: 180 }]->(STOP_1166841),
#   (STOP_2468)-[:TRANSFER { transfer_time: 480 }]->(STOP_1715),
#   (STOP_2468)-[:TRANSFER { transfer_time: 131 }]->(STOP_1724),
#   (STOP_2468)-[:TRANSFER { transfer_time: 480 }]->(STOP_2460),
#   (STOP_2468)-[:TRANSFER { transfer_time: 139 }]->(STOP_2469),
#   (STOP_2469)-[:TRANSFER { transfer_time: 480 }]->(STOP_1715),
#   (STOP_2469)-[:TRANSFER { transfer_time: 480 }]->(STOP_2460),
#   (STOP_2476)-[:TRANSFER { transfer_time: 99 }]->(STOP_1667),
#   (STOP_2476)-[:TRANSFER { transfer_time: 57 }]->(STOP_2477),
#   (STOP_2485)-[:TRANSFER { transfer_time: 116 }]->(STOP_1674),
#   (STOP_2485)-[:TRANSFER { transfer_time: 127 }]->(STOP_1676),
#   (STOP_2485)-[:TRANSFER { transfer_time: 127 }]->(STOP_2484),
#   (STOP_2485)-[:TRANSFER { transfer_time: 125 }]->(STOP_2486),
#   (STOP_2486)-[:TRANSFER { transfer_time: 234 }]->(STOP_1674),
#   (STOP_2486)-[:TRANSFER { transfer_time: 245 }]->(STOP_2484),
#   (STOP_2487)-[:TRANSFER { transfer_time: 119 }]->(STOP_1678),
#   (STOP_2487)-[:TRANSFER { transfer_time: 90 }]->(STOP_2488),
#   (STOP_2497)-[:TRANSFER { transfer_time: 96 }]->(STOP_1637),
#   (STOP_2497)-[:TRANSFER { transfer_time: 81 }]->(STOP_2517),
#   (STOP_2510)-[:TRANSFER { transfer_time: 72 }]->(STOP_1629),
#   (STOP_2510)-[:TRANSFER { transfer_time: 72 }]->(STOP_2509),
#   (STOP_2525)-[:TRANSFER { transfer_time: 90 }]->(STOP_1763),
#   (STOP_2525)-[:TRANSFER { transfer_time: 90 }]->(STOP_2409),
#   (STOP_2528)-[:TRANSFER { transfer_time: 98 }]->(STOP_1794),
#   (STOP_2528)-[:TRANSFER { transfer_time: 102 }]->(STOP_2404),
#   (STOP_2531)-[:TRANSFER { transfer_time: 153 }]->(STOP_1832),
#   (STOP_2531)-[:TRANSFER { transfer_time: 151 }]->(STOP_2371),
#   (STOP_2533)-[:TRANSFER { transfer_time: 105 }]->(STOP_1845),
#   (STOP_2533)-[:TRANSFER { transfer_time: 106 }]->(STOP_2312),
#   (STOP_2535)-[:TRANSFER { transfer_time: 172 }]->(STOP_1883),
#   (STOP_2535)-[:TRANSFER { transfer_time: 170 }]->(STOP_2279),
#   (STOP_2548)-[:TRANSFER { transfer_time: 98 }]->(STOP_2066),
#   (STOP_2548)-[:TRANSFER { transfer_time: 132 }]->(STOP_2115),
#   (STOP_3343755)-[:TRANSFER { transfer_time: 180 }]->(STOP_1657),
#   (STOP_3343755)-[:TRANSFER { transfer_time: 180 }]->(STOP_1916),
#   (STOP_3343755)-[:TRANSFER { transfer_time: 180 }]->(STOP_2241),
#   (STOP_3343755)-[:TRANSFER { transfer_time: 180 }]->(STOP_2537),
#   (STOP_3343756)-[:TRANSFER { transfer_time: 180 }]->(STOP_1657),
#   (STOP_3343756)-[:TRANSFER { transfer_time: 180 }]->(STOP_1916),
#   (STOP_3343756)-[:TRANSFER { transfer_time: 180 }]->(STOP_2241),
#   (STOP_3343756)-[:TRANSFER { transfer_time: 180 }]->(STOP_2537),
#   (STOP_3343761)-[:TRANSFER { transfer_time: 180 }]->(STOP_1897),
#   (STOP_3343761)-[:TRANSFER { transfer_time: 180 }]->(STOP_2293),
#   (STOP_3343762)-[:TRANSFER { transfer_time: 180 }]->(STOP_1897),
#   (STOP_3343762)-[:TRANSFER { transfer_time: 180 }]->(STOP_2293),
#   (STOP_3343763)-[:TRANSFER { transfer_time: 180 }]->(STOP_1980),
#   (STOP_3343763)-[:TRANSFER { transfer_time: 180 }]->(STOP_1982),
#   (STOP_3343763)-[:TRANSFER { transfer_time: 180 }]->(STOP_2170),
#   (STOP_3343763)-[:TRANSFER { transfer_time: 180 }]->(STOP_2172),
#   (STOP_3343764)-[:TRANSFER { transfer_time: 180 }]->(STOP_1980),
#   (STOP_3343764)-[:TRANSFER { transfer_time: 180 }]->(STOP_1982),
#   (STOP_3343764)-[:TRANSFER { transfer_time: 180 }]->(STOP_2170),
#   (STOP_3343764)-[:TRANSFER { transfer_time: 180 }]->(STOP_2172),
#   (STOP_3343765)-[:TRANSFER { transfer_time: 180 }]->(STOP_1166838),
#   (STOP_3343765)-[:TRANSFER { transfer_time: 180 }]->(STOP_1166839),
#   (STOP_3343765)-[:TRANSFER { transfer_time: 180 }]->(STOP_1869),
#   (STOP_3343765)-[:TRANSFER { transfer_time: 180 }]->(STOP_2336),
#   (STOP_3343766)-[:TRANSFER { transfer_time: 180 }]->(STOP_1166838),
#   (STOP_3343766)-[:TRANSFER { transfer_time: 180 }]->(STOP_1166839),
#   (STOP_3343766)-[:TRANSFER { transfer_time: 180 }]->(STOP_1869),
#   (STOP_3343766)-[:TRANSFER { transfer_time: 180 }]->(STOP_2336),
#   (STOP_3343767)-[:TRANSFER { transfer_time: 180 }]->(STOP_1846),
#   (STOP_3343767)-[:TRANSFER { transfer_time: 180 }]->(STOP_1847),
#   (STOP_3343767)-[:TRANSFER { transfer_time: 180 }]->(STOP_2313),
#   (STOP_3343767)-[:TRANSFER { transfer_time: 180 }]->(STOP_2314),
#   (STOP_3343768)-[:TRANSFER { transfer_time: 180 }]->(STOP_1846),
#   (STOP_3343768)-[:TRANSFER { transfer_time: 180 }]->(STOP_1847),
#   (STOP_3343768)-[:TRANSFER { transfer_time: 180 }]->(STOP_2313),
#   (STOP_3343768)-[:TRANSFER { transfer_time: 180 }]->(STOP_2314),
#   (STOP_3343769)-[:TRANSFER { transfer_time: 180 }]->(STOP_1702),
#   (STOP_3343769)-[:TRANSFER { transfer_time: 180 }]->(STOP_2447),
#   (STOP_3343770)-[:TRANSFER { transfer_time: 180 }]->(STOP_1702),
#   (STOP_3343770)-[:TRANSFER { transfer_time: 180 }]->(STOP_2447),
#   (STOP_3343771)-[:TRANSFER { transfer_time: 180 }]->(STOP_1712),
#   (STOP_3343771)-[:TRANSFER { transfer_time: 180 }]->(STOP_2457),
#   (STOP_3343772)-[:TRANSFER { transfer_time: 180 }]->(STOP_1712),
#   (STOP_3343772)-[:TRANSFER { transfer_time: 180 }]->(STOP_2457),
#   (STOP_3343773)-[:TRANSFER { transfer_time: 180 }]->(STOP_2001),
#   (STOP_3343773)-[:TRANSFER { transfer_time: 180 }]->(STOP_2190),
#   (STOP_3343774)-[:TRANSFER { transfer_time: 180 }]->(STOP_2001),
#   (STOP_3343774)-[:TRANSFER { transfer_time: 180 }]->(STOP_2190),
#   (STOP_3343775)-[:TRANSFER { transfer_time: 180 }]->(STOP_1677),
#   (STOP_3343775)-[:TRANSFER { transfer_time: 180 }]->(STOP_1678),
#   (STOP_3343775)-[:TRANSFER { transfer_time: 180 }]->(STOP_2487),
#   (STOP_3343775)-[:TRANSFER { transfer_time: 180 }]->(STOP_2488),
#   (STOP_3343776)-[:TRANSFER { transfer_time: 180 }]->(STOP_1677),
#   (STOP_3343776)-[:TRANSFER { transfer_time: 180 }]->(STOP_1678),
#   (STOP_3343776)-[:TRANSFER { transfer_time: 180 }]->(STOP_2487),
#   (STOP_3343776)-[:TRANSFER { transfer_time: 180 }]->(STOP_2488),
#   (STOP_3343777)-[:TRANSFER { transfer_time: 180 }]->(STOP_1647),
#   (STOP_3343777)-[:TRANSFER { transfer_time: 180 }]->(STOP_1766),
#   (STOP_3343777)-[:TRANSFER { transfer_time: 180 }]->(STOP_1767),
#   (STOP_3343777)-[:TRANSFER { transfer_time: 180 }]->(STOP_2376),
#   (STOP_3343777)-[:TRANSFER { transfer_time: 180 }]->(STOP_2377),
#   (STOP_3343777)-[:TRANSFER { transfer_time: 180 }]->(STOP_2527),
#   (STOP_3343777)-[:TRANSFER { transfer_time: 180 }]->(STOP_967988),
#   (STOP_3343777)-[:TRANSFER { transfer_time: 180 }]->(STOP_967989),
#   (STOP_3343778)-[:TRANSFER { transfer_time: 180 }]->(STOP_1647),
#   (STOP_3343778)-[:TRANSFER { transfer_time: 180 }]->(STOP_1766),
#   (STOP_3343778)-[:TRANSFER { transfer_time: 180 }]->(STOP_1767),
#   (STOP_3343778)-[:TRANSFER { transfer_time: 180 }]->(STOP_2376),
#   (STOP_3343778)-[:TRANSFER { transfer_time: 180 }]->(STOP_2377),
#   (STOP_3343778)-[:TRANSFER { transfer_time: 180 }]->(STOP_2527),
#   (STOP_3343778)-[:TRANSFER { transfer_time: 180 }]->(STOP_967988),
#   (STOP_3343778)-[:TRANSFER { transfer_time: 180 }]->(STOP_967989),
#   (STOP_3343785)-[:TRANSFER { transfer_time: 180 }]->(STOP_2062),
#   (STOP_3343785)-[:TRANSFER { transfer_time: 180 }]->(STOP_2063),
#   (STOP_3343785)-[:TRANSFER { transfer_time: 180 }]->(STOP_2111),
#   (STOP_3343785)-[:TRANSFER { transfer_time: 180 }]->(STOP_2112),
#   (STOP_3343786)-[:TRANSFER { transfer_time: 180 }]->(STOP_2062),
#   (STOP_3343786)-[:TRANSFER { transfer_time: 180 }]->(STOP_2063),
#   (STOP_3343786)-[:TRANSFER { transfer_time: 180 }]->(STOP_2111),
#   (STOP_3343786)-[:TRANSFER { transfer_time: 180 }]->(STOP_2112),
#   (STOP_3343791)-[:TRANSFER { transfer_time: 180 }]->(STOP_1698),
#   (STOP_3343791)-[:TRANSFER { transfer_time: 180 }]->(STOP_2443),
#   (STOP_3343792)-[:TRANSFER { transfer_time: 180 }]->(STOP_1698),
#   (STOP_3343792)-[:TRANSFER { transfer_time: 180 }]->(STOP_2443),
#   (STOP_3343795)-[:TRANSFER { transfer_time: 180 }]->(STOP_2081),
#   (STOP_3343795)-[:TRANSFER { transfer_time: 180 }]->(STOP_2094),
#   (STOP_3343796)-[:TRANSFER { transfer_time: 180 }]->(STOP_2081),
#   (STOP_3343796)-[:TRANSFER { transfer_time: 180 }]->(STOP_2094),
#   (STOP_967988)-[:TRANSFER { transfer_time: 180 }]->(STOP_1647),
#   (STOP_967988)-[:TRANSFER { transfer_time: 180 }]->(STOP_2527),
#   (STOP_967989)-[:TRANSFER { transfer_time: 180 }]->(STOP_1647),
#   (STOP_967989)-[:TRANSFER { transfer_time: 180 }]->(STOP_2527)
